# %%
import pandas as pd
import requests
import json
import datetime

# %% [markdown]
# ### Set up:

# %%
# define all necessary functions:
def connect_to_twitter(token):
    bearer_token = token
    return {"Authorization": "Bearer {}".format(bearer_token)}

def make_request(headers, params, url):
    url=url
    params=params
    return requests.request("GET", url, params=params, headers=headers).json()

def make_df(response):
    return pd.DataFrame(response['data'])

# %%
# read credentials:
creds = pd.read_csv(f'../creds/CredentialsStandAPI.csv')

# define bearer_token:
bearer_token = creds.iloc[0]['bearer_token']

# %%
# read twitter handles and convert to list:
twitter_handles=pd.read_excel('data/twitter_handles.xlsx').dropna(axis=0)
#twitter_handles=twitter_handles.dropna(axis=0) # remove outlets for which there is no Twitter handle
twitter_handles = twitter_handles['twitter_handle'].tolist()

# %%
# connect to API
headers = connect_to_twitter(bearer_token)

# %% [markdown]
# ### Run Test with only few Outlets: Loop over List of Twitter handles

# %%
handles=['19thnews', 'ABC', 'TheAdvocateMag', 'AFPFactCheck', 'AJEnglish', 'aldotcom', 'AlterNet', 'theamgreatness', 'AmerIndependent']

# %%
# url => later I need http://api.twitter.com/2/tweets/search/all
url="http://api.twitter.com/2/tweets/search/recent"

# create empty dict:
response={}


for handle in handles:
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime('2021-10-24T00:00:00+0200', '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time': datetime.datetime.strptime('2021-10-24T23:59:59+0200', '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
            'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
            'max_results': 100} # default is 10, max possible is 100
    
    response[f'{handle}']=make_request(headers, params, url)

# %%
# from dictionary to dataframe:
tweets = pd.DataFrame(list(response.items()))

# %%
# create empty dataframe with the respective columns
all_tweets = pd.DataFrame(columns=['entities', 'text', 'author_id', 'id', 'conversation_id', 'created_at', 'attachments', 'referenced_tweets'])

# concatenate all dataframes into one large
for i in range(0, len(tweets)):
    all_tweets=pd.concat([all_tweets, make_df(tweets.iloc[i,1])])

# %%
all_tweets
# Out:
#                                              entities  \
# 0   {'urls': [{'start': 198, 'end': 221, 'url': 'h...
# 0   {'annotations': [{'start': 14, 'end': 24, 'pro...
# 1   {'annotations': [{'start': 107, 'end': 112, 'p...
# 2   {'annotations': [{'start': 0, 'end': 11, 'prob...
# 3   {'annotations': [{'start': 35, 'end': 41, 'pro...
# ..                                                ...
# 2   {'urls': [{'start': 210, 'end': 233, 'url': 'h...
# 3   {'urls': [{'start': 224, 'end': 247, 'url': 'h...
# 4   {'urls': [{'start': 177, 'end': 200, 'url': 'h...
# 5   {'urls': [{'start': 104, 'end': 127, 'url': 'h...
# 6   {'urls': [{'start': 248, 'end': 271, 'url': 'h...
#
#                                                  text            author_id  \
# 0   During the pandemic, 1 in 4 women in the study...  1219278784693768193
# 0   Parade-loving New Orleans is about to get its ...             28785486
# 1   A group of about 2,000 mainly Central American...             28785486
# 2   Donald Trump's new social media app could prov...             28785486
# 3   PUMPKIN PARTY: Animals at a zoo in Chicago wer...             28785486
# ..                                                ...                  ...
# 2   Nearly three years after the massacre at the T...           2467720274
# 3   Loudoun County parents say the people who have...           2467720274
# 4   The Biden administration says that increased I...           2467720274
# 5   Moving forward, Bannon could face up to 12 mon...           2467720274
# 6   @ClyburnSC06: "The significant mismanagement o...           2467720274
#
#                      id      conversation_id                created_at  \
# 0   1452281979622330373  1452281979622330373  2021-10-24T14:33:00.000Z
# 0   1452394057171447823  1452394057171447823  2021-10-24T21:58:22.000Z
# 1   1452388445217824769  1452388445217824769  2021-10-24T21:36:04.000Z
# 2   1452383946122092548  1452383946122092548  2021-10-24T21:18:11.000Z
# 3   1452379412729638927  1452379412729638927  2021-10-24T21:00:10.000Z
# ..                  ...                  ...                       ...
# 2   1452276195949793287  1452276195949793287  2021-10-24T14:10:01.000Z
# 3   1452243485722034189  1452243485722034189  2021-10-24T12:00:03.000Z
# 4   1452093741494423555  1452093741494423555  2021-10-24T02:05:01.000Z
# 5   1452062534488444933  1452062534488444933  2021-10-24T00:01:00.000Z
# 6   1452032334090444809  1452032334090444809  2021-10-23T22:01:00.000Z
#
#                                    attachments referenced_tweets
# 0                                          NaN               NaN
# 0                                          NaN               NaN
# 1                                          NaN               NaN
# 2                                          NaN               NaN
# 3   {'media_keys': ['13_1451536997651202060']}               NaN
# ..                                         ...               ...
# 2                                          NaN               NaN
# 3                                          NaN               NaN
# 4                                          NaN               NaN
# 5                                          NaN               NaN
# 6                                          NaN               NaN
#
# [227 rows x 8 columns]

# %% [markdown]
# ### Retreave IDs for each outlet (by Twitter handle)

# %%
# new request:
# define new parameters
url="https://api.twitter.com/2/users/by"

# create empty dict:
users={}


for handle in handles:
    params={'usernames': f'{handle}'} # add Twitter handle for outlets here
    
    users[f'{handle}']=make_request(headers, params, url)

# %%
# dict to dataframe:
df_ids = pd.DataFrame(list(users.items()))

# %%
# extract user ids for each outlet from dictionary column:
user_ids=[]
for i in range(0, len(df_ids)):
    user_ids.append(df_ids.iloc[i,1]['data'][0]['id'])

# %%
df_ids[1]=user_ids
df_ids=df_ids.rename(columns={0: "username", 1: "author_id"})

# %%
df_ids
# Out:
#           username            author_id
# 0         19thnews  1219278784693768193
# 1              ABC             28785486
# 2   TheAdvocateMag             21692297
# 3     AFPFactCheck  1002203254065950720
# 4        AJEnglish              4970411
# 5         aldotcom             14528874
# 6         AlterNet             18851248
# 7   theamgreatness   749016639287414784
# 8  AmerIndependent           2467720274

# %% [markdown]
# ### Add Twitter handle (=username) to each tweet (join via author_id)

# %%
# join all_tweets and df_ids to assign outlet name to each tweet:
result = pd.merge(all_tweets, df_ids, on="author_id").sort_values('username')

# %%
result
# Out:
#                                               entities  \
# 0    {'urls': [{'start': 198, 'end': 221, 'url': 'h...
# 68   {'annotations': [{'start': 4, 'end': 7, 'proba...
# 67   {'urls': [{'start': 80, 'end': 103, 'url': 'ht...
# 66   {'annotations': [{'start': 66, 'end': 69, 'pro...
# 64   {'urls': [{'start': 253, 'end': 276, 'url': 'h...
# ..                                                 ...
# 216  {'annotations': [{'start': 0, 'end': 14, 'prob...
# 217  {'annotations': [{'start': 0, 'end': 16, 'prob...
# 218  {'annotations': [{'start': 0, 'end': 8, 'proba...
# 219  {'annotations': [{'start': 0, 'end': 12, 'prob...
# 215  {'annotations': [{'start': 0, 'end': 14, 'prob...
#
#                                                   text            author_id  \
# 0    During the pandemic, 1 in 4 women in the study...  1219278784693768193
# 68   The U.S. is welcoming tens of thousands of Afg...             28785486
# 67   As people head indoors for the winter, coronav...             28785486
# 66   "There was a lot of pressure on me to not make...             28785486
# 64   "It can never be just what we saw in 2017. It'...             28785486
# ..                                                 ...                  ...
# 216  Douglas Dechert: "The stark choice in the upco...   749016639287414784
# 217  Josiah Lippincott: "Americans must stop granti...   749016639287414784
# 218  Adam Mill: "A punk from the 1980s would not re...   749016639287414784
# 219  Roger Kimball: "The Soviets had the gulag, we ...   749016639287414784
# 215  Joshua Mitchell: "Equality In Servitude: From ...   749016639287414784
#
#                       id      conversation_id                created_at  \
# 0    1452281979622330373  1452281979622330373  2021-10-24T14:33:00.000Z
# 68   1452142958124441604  1452142958124441604  2021-10-24T05:20:35.000Z
# 67   1452148243362721794  1452148243362721794  2021-10-24T05:41:35.000Z
# 66   1452152906619269125  1452152906619269125  2021-10-24T06:00:07.000Z
# 64   1452168019409620994  1452168019409620994  2021-10-24T07:00:10.000Z
# ..                   ...                  ...                       ...
# 216  1452276196293726208  1452276196293726208  2021-10-24T14:10:01.000Z
# 217  1452273714398220295  1452273714398220295  2021-10-24T14:00:10.000Z
# 218  1452271163044999172  1452271163044999172  2021-10-24T13:50:01.000Z
# 219  1452268647393681412  1452268647393681412  2021-10-24T13:40:02.000Z
# 215  1452278712829976578  1452278712829976578  2021-10-24T14:20:01.000Z
#
#                                     attachments referenced_tweets  \
# 0                                           NaN               NaN
# 68                                          NaN               NaN
# 67                                          NaN               NaN
# 66   {'media_keys': ['13_1451608383036002314']}               NaN
# 64   {'media_keys': ['13_1451607945062584356']}               NaN
# ..                                          ...               ...
# 216                                         NaN               NaN
# 217                                         NaN               NaN
# 218                                         NaN               NaN
# 219                                         NaN               NaN
# 215                                         NaN               NaN
#
#            username
# 0          19thnews
# 68              ABC
# 67              ABC
# 66              ABC
# 64              ABC
# ..              ...
# 216  theamgreatness
# 217  theamgreatness
# 218  theamgreatness
# 219  theamgreatness
# 215  theamgreatness
#
# [227 rows x 9 columns]

# %% [markdown]
# ### Run Test with only few Outlets: Loop over List of Twitter handles AND start, end date

# %%
# define parameters:
url="http://api.twitter.com/2/tweets/search/recent"

# read time_stamps:
time_stamps=pd.read_csv('data/time_stamps.csv')
start_dates=time_stamps['start'].to_list() # all start dates to list
end_dates=time_stamps['end'].to_list() # all end dates to list

# %%
# define request:

# create empty dict:
responses_with_dates={}


for handle in handles:
    responses_with_dates[f'{handle}']={}
    
    for start, end in zip(start_dates, end_dates):
        params={'query': f'from:{handle}', # add Twitter handle for outlets here
                'start_time': datetime.datetime.strptime(start, '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
                'end_time': datetime.datetime.strptime(end, '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
                'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
                'max_results': 100} # default is 10, max possible is 100
        
        responses_with_dates[f'{handle}'][f'{start}, {end}']=make_request(headers, params, url)

# %%
# dict to dataframe:
df_dates = pd.DataFrame(list(responses_with_dates.items()))

# %%
# concatenate all tweets to one dataframe:
all_tweets_dates=pd.DataFrame(columns=['entities', 'text', 'author_id', 'id', 'conversation_id', 'created_at', 'attachments', 'referenced_tweets'])

for i in range(0, len(df_dates)):
    for j in range(0, len(pd.DataFrame(list(df_dates.iloc[0,1].items())))):
        all_tweets_dates=pd.concat([all_tweets_dates, make_df(pd.DataFrame(list(df_dates.iloc[i,1].items())).iloc[j,1])])

# %%
all_tweets_dates
# Out:
#                                              entities  \
# 0   {'annotations': [{'start': 139, 'end': 143, 'p...
# 1   {'annotations': [{'start': 4, 'end': 11, 'prob...
# 2   {'annotations': [{'start': 122, 'end': 127, 'p...
# 3   {'annotations': [{'start': 137, 'end': 140, 'p...
# 4   {'annotations': [{'start': 0, 'end': 12, 'prob...
# ..                                                ...
# 15  {'annotations': [{'start': 17, 'end': 19, 'pro...
# 16  {'annotations': [{'start': 0, 'end': 12, 'prob...
# 17  {'annotations': [{'start': 0, 'end': 9, 'proba...
# 18  {'annotations': [{'start': 32, 'end': 36, 'pro...
# 19  {'annotations': [{'start': 0, 'end': 4, 'proba...
#
#                                                  text            author_id  \
# 0   The court will not specifically examine the co...  1219278784693768193
# 1   One Michigan state rep said men in the legisla...  1219278784693768193
# 2   Women make up more than half of the American p...  1219278784693768193
# 3   Women aged 40 to 65 have been hit hard by the ...  1219278784693768193
# 4   Kamala Harris made history in 2020 as the firs...  1219278784693768193
# ..                                                ...                  ...
# 15  Wife of indicted GOP congressman says charges ...           2467720274
# 16  Supreme Court to hear case on spiritual advise...           2467720274
# 17  Republican leaders support jobless benefits — ...           2467720274
# 18  In her campaign kickoff speech, Fiore promised...           2467720274
# 19  Trump is starting his own social media platfor...           2467720274
#
#                      id      conversation_id                created_at  \
# 0   1451999872710754304  1451999872710754304  2021-10-23T19:52:01.000Z
# 1   1451999871536353285  1451999871536353285  2021-10-23T19:52:00.000Z
# 2   1451950297589460994  1451950297589460994  2021-10-23T16:35:01.000Z
# 3   1451935949030662158  1451935949030662158  2021-10-23T15:38:00.000Z
# 4   1451746701669277696  1451746701669277696  2021-10-23T03:06:00.000Z
# ..                  ...                  ...                       ...
# 15  1452671526814240774  1452671526814240774  2021-10-25T16:20:55.000Z
# 16  1452646697826455552  1452646697826455552  2021-10-25T14:42:16.000Z
# 17  1452629865253986311  1452629865253986311  2021-10-25T13:35:23.000Z
# 18  1452424678258221058  1452424678258221058  2021-10-25T00:00:02.000Z
# 19  1452394725890199555  1452394725890199555  2021-10-24T22:01:01.000Z
#
#    attachments referenced_tweets
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
# ..         ...               ...
# 15         NaN               NaN
# 16         NaN               NaN
# 17         NaN               NaN
# 18         NaN               NaN
# 19         NaN               NaN
#
# [749 rows x 8 columns]

# %%
# join with df_ids:
result_tweets_dates = pd.merge(all_tweets_dates, df_ids, on="author_id").sort_values(by=['username', 'created_at'])

# %%
result_tweets_dates
# Out:
#                                               entities  \
# 6    {'urls': [{'start': 199, 'end': 222, 'url': 'h...
# 5    {'annotations': [{'start': 0, 'end': 10, 'prob...
# 4    {'annotations': [{'start': 0, 'end': 12, 'prob...
# 3    {'annotations': [{'start': 137, 'end': 140, 'p...
# 2    {'annotations': [{'start': 122, 'end': 127, 'p...
# ..                                                 ...
# 703  {'urls': [{'start': 256, 'end': 279, 'url': 'h...
# 702  {'urls': [{'start': 249, 'end': 272, 'url': 'h...
# 701  {'urls': [{'start': 239, 'end': 262, 'url': 'h...
# 700  {'urls': [{'start': 85, 'end': 108, 'url': 'ht...
# 699  {'urls': [{'start': 220, 'end': 243, 'url': 'h...
#
#                                                   text            author_id  \
# 6    Black women candidates could make gains — and ...  1219278784693768193
# 5    White House reveals nation’s first gender equi...  1219278784693768193
# 4    Kamala Harris made history in 2020 as the firs...  1219278784693768193
# 3    Women aged 40 to 65 have been hit hard by the ...  1219278784693768193
# 2    Women make up more than half of the American p...  1219278784693768193
# ..                                                 ...                  ...
# 703  The last 12 months saw a record total of over ...   749016639287414784
# 702  A series of new leaks from Big Tech giant Face...   749016639287414784
# 701  A group of two dozen members of Congress from ...   749016639287414784
# 700  Morning Greatness: Government Spends Tax Dolla...   749016639287414784
# 699  Thousands of city employees protested on Monda...   749016639287414784
#
#                       id      conversation_id                created_at  \
# 6    1451693099273662464  1451693099273662464  2021-10-22T23:33:00.000Z
# 5    1451706438317924356  1451706438317924356  2021-10-23T00:26:00.000Z
# 4    1451746701669277696  1451746701669277696  2021-10-23T03:06:00.000Z
# 3    1451935949030662158  1451935949030662158  2021-10-23T15:38:00.000Z
# 2    1451950297589460994  1451950297589460994  2021-10-23T16:35:01.000Z
# ..                   ...                  ...                       ...
# 703  1452645197553283084  1452645197553283084  2021-10-25T14:36:18.000Z
# 702  1452645525753319428  1452645525753319428  2021-10-25T14:37:36.000Z
# 701  1452645711963643913  1452645711963643913  2021-10-25T14:38:21.000Z
# 700  1452645877051502592  1452645877051502592  2021-10-25T14:39:00.000Z
# 699  1452734255096811523  1452734255096811523  2021-10-25T20:30:11.000Z
#
#     attachments referenced_tweets        username
# 6           NaN               NaN        19thnews
# 5           NaN               NaN        19thnews
# 4           NaN               NaN        19thnews
# 3           NaN               NaN        19thnews
# 2           NaN               NaN        19thnews
# ..          ...               ...             ...
# 703         NaN               NaN  theamgreatness
# 702         NaN               NaN  theamgreatness
# 701         NaN               NaN  theamgreatness
# 700         NaN               NaN  theamgreatness
# 699         NaN               NaN  theamgreatness
#
# [749 rows x 9 columns]

# %% [markdown]
# ### Run Test with only few Outlets: Loop over List of Twitter handles, start date and end date
#
# actually, need combination of twitter handle, start date and end date >> idea: for handle, start, end in zip(handles, start_dates, end_dates)

# %%
# read twitter handles + start & end date:
data = pd.read_csv('data/outlets_time_stamps.csv')

# %%
# define parameters:
url="http://api.twitter.com/2/tweets/search/recent"

twitter_handles=data['handle'].tolist()
start_dates=data['start'].tolist()
end_dates=data['end'].tolist()

# %%
# define request:

# create empty dict:
responses_individual_dates={}


for handle, start, end in zip(twitter_handles, start_dates, end_dates):
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime(start, '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time': datetime.datetime.strptime(end, '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
            'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
            'max_results': 100} # default is 10, max possible is 100
    
    responses_individual_dates[f'{handle}']=make_request(headers, params, url)

# %%
# dict to dataframe:
df_ind_dates = pd.DataFrame(list(responses_individual_dates.items()))

# %%
df_ind_dates
# Out:
#                 0                                                  1
# 0        19thnews  {'data': [{'id': '1453077632900292612', 'conve...
# 1             ABC  {'data': [{'entities': {'urls': [{'start': 255...
# 2  TheAdvocateMag  {'data': [{'id': '1453836292593111043', 'autho...

# %%
# create empty dataframe with the respective columns
tweets_ind_dates = pd.DataFrame(columns=['entities', 'text', 'author_id', 'id', 'conversation_id', 'created_at', 'attachments', 'referenced_tweets'])

# concatenate all dataframes into one large
for i in range(0, len(df_ind_dates)):
    tweets_ind_dates=pd.concat([tweets_ind_dates, make_df(df_ind_dates.iloc[i,1])])

# %%
tweets_ind_dates
# Out:
#                                              entities  \
# 0   {'urls': [{'start': 193, 'end': 216, 'url': 'h...
# 1   {'mentions': [{'start': 3, 'end': 10, 'usernam...
# 2   {'urls': [{'start': 237, 'end': 260, 'url': 'h...
# 3   {'mentions': [{'start': 3, 'end': 15, 'usernam...
# 4   {'mentions': [{'start': 3, 'end': 9, 'username...
# ..                                                ...
# 5   {'urls': [{'start': 114, 'end': 137, 'url': 'h...
# 6   {'urls': [{'start': 172, 'end': 195, 'url': 'h...
# 7   {'urls': [{'start': 179, 'end': 202, 'url': 'h...
# 8   {'urls': [{'start': 135, 'end': 158, 'url': 'h...
# 9   {'urls': [{'start': 133, 'end': 156, 'url': 'h...
#
#                                                  text            author_id  \
# 0   Intersex advocates and parents of intersex kid...  1219278784693768193
# 1   RT @flpeir: Roughly 1 in 2,000 babies demonstr...  1219278784693768193
# 2   Washington Secretary of State Kim Wyman has ac...  1219278784693768193
# 3   RT @bcrodriguez: Multiple senators are pushing...  1219278784693768193
# 4   RT @amzam: With abortion arguments looming, @A...  1219278784693768193
# ..                                                ...                  ...
# 5   .@CampusPride named 180 campuses across the na...             21692297
# 6   Italy’s Senate has quashed a bill that would h...             21692297
# 7   "Time on Two Crosses: The Collected Writings o...             21692297
# 8   Dave Chappelle said he's willing to speak with...             21692297
# 9   "We want to say that it's never too late to sh...             21692297
#
#                      id      conversation_id                created_at  \
# 0   1453077632900292612  1453077632900292612  2021-10-26T19:14:39.000Z
# 1   1453077216787451906  1453077216787451906  2021-10-26T19:13:00.000Z
# 2   1453057397858217990  1453057397858217990  2021-10-26T17:54:14.000Z
# 3   1453049316348547076  1453049316348547076  2021-10-26T17:22:08.000Z
# 4   1453045339166953475  1453045339166953475  2021-10-26T17:06:19.000Z
# ..                  ...                  ...                       ...
# 5   1453724738568671236  1453724738568671236  2021-10-28T14:06:01.000Z
# 6   1453548210455146498  1453548210455146498  2021-10-28T02:24:33.000Z
# 7   1453512294831251457  1453512294831251457  2021-10-28T00:01:50.000Z
# 8   1453497592910782467  1453497592910782467  2021-10-27T23:03:25.000Z
# 9   1453481636134154243  1453481636134154243  2021-10-27T22:00:01.000Z
#
#    attachments                                  referenced_tweets
# 0          NaN                                                NaN
# 1          NaN  [{'type': 'retweeted', 'id': '1453075273071595...
# 2          NaN                                                NaN
# 3          NaN  [{'type': 'retweeted', 'id': '1453046682300604...
# 4          NaN  [{'type': 'retweeted', 'id': '1453044964867313...
# ..         ...                                                ...
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
#
# [134 rows x 8 columns]

# %%
# join tweets_ind_dates and df_ids to assign outlet name to each tweet:
final = pd.merge(tweets_ind_dates, df_ids, on="author_id").sort_values(by=['username', 'created_at'])

# %% [markdown]
# ### Run Test with only few Outlets: While loop over dates, If loop over handles
#
# - one response per day to keep limit of 500 tweets per response

# %%
# define variables:

# 1. list of handles
handles=['19thnews', 'ABC', 'TheAdvocateMag', 'AFPFactCheck', 'AJEnglish', 'aldotcom', 'AlterNet', 'theamgreatness', 'AmerIndependent']


# 2. start and end date
start_date_obj = datetime.datetime.strptime('2021-10-28T00:00:00+0100', '%Y-%m-%dT%H:%M:%S%z')
end_date_obj = datetime.datetime.strptime('2021-10-29T00:00:00+0100', '%Y-%m-%dT%H:%M:%S%z')
cut_off = datetime.datetime.strptime('2021-11-03T00:00:00+0100', '%Y-%m-%dT%H:%M:%S%z')


# 3. url
url="http://api.twitter.com/2/tweets/search/recent"

# %%
# loop

# create empty dict:
test_dict={}


while start_date_obj != cut_off:
    test_dict[f'{start_date_obj}, {end_date_obj}']={}
    
    for handle in handles:
        params={'query': f'from:{handle}', # add Twitter handle for outlets here
                'start_time': start_date_obj.isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
                'end_time': end_date_obj.isoformat(), 
                'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
                'max_results': 100} # default is 10, max possible is 100
        
        test_dict[f'{start_date_obj}, {end_date_obj}'][f'{handle}']=make_request(headers, params, url)
        
    start_date_obj += datetime.timedelta(days=1)
    end_date_obj += datetime.timedelta(days=1)

# %%
test_dict
# Out:
# {'2021-10-28 00:00:00+01:00, 2021-10-29 00:00:00+01:00': {'19thnews': {'data': [{'conversation_id': '1453827691141025800',
#      'id': '1453827691141025800',
#      'entities': {'annotations': [{'start': 18,
#         'end': 23,
#         'probability': 0.8423,
#         'type': 'Organization',
#         'normalized_text': 'Senate'},
#        {'start': 112,
#         'end': 124,
#         'probability': 0.6511,
#         'type': 'Organization',
#         'normalized_text': 'Supreme Court'},
#        {'start': 128,
#         'end': 136,
#         'probability': 0.5726,
#         'type': 'Person',
#         'normalized_text': 'Elizabeth'}],
#       'mentions': [{'start': 3,
#         'end': 16,
#         'username': 'AmandaBecker',
#         'id': '233985354'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453813778018144265'}],
#      'text': 'RT @AmandaBecker: Senate confirms second ever woman solicitor general, who represents federal government before Supreme Court — Elizabeth P…',
#      'created_at': '2021-10-28T20:55:07.000Z'},
#     {'conversation_id': '1453827518222450690',
#      'id': '1453827518222450690',
#      'entities': {'annotations': [{'start': 0,
#         'end': 17,
#         'probability': 0.9866,
#         'type': 'Person',
#         'normalized_text': 'Elizabeth Prelogar'},
#        {'start': 57,
#         'end': 67,
#         'probability': 0.9456,
#         'type': 'Person',
#         'normalized_text': 'Elena Kagan'},
#        {'start': 168,
#         'end': 172,
#         'probability': 0.8357,
#         'type': 'Place',
#         'normalized_text': 'Texas'}],
#       'urls': [{'start': 188,
#         'end': 211,
#         'url': 'https://t.co/xShh1ceTUY',
#         'expanded_url': 'https://19thnews.org/2021/10/elizabeth-prelogar-solicitor-general-confirmed/',
#         'display_url': '19thnews.org/2021/10/elizab…'}]},
#      'author_id': '1219278784693768193',
#      'text': 'Elizabeth Prelogar clerked for now-Supreme Court Justice Elena Kagan, who was the first woman solicitor general. Her confirmation comes days before oral arguments on a Texas abortion ban. https://t.co/xShh1ceTUY',
#      'created_at': '2021-10-28T20:54:25.000Z'},
#     {'conversation_id': '1453793645740560393',
#      'id': '1453793645740560393',
#      'entities': {'annotations': [{'start': 49,
#         'end': 53,
#         'probability': 0.9293,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'urls': [{'start': 241,
#         'end': 264,
#         'url': 'https://t.co/k1b61GDGCC',
#         'expanded_url': 'https://bit.ly/3pMkGit',
#         'display_url': 'bit.ly/3pMkGit'}]},
#      'author_id': '1219278784693768193',
#      'text': '“No one got everything they want, including me,” Biden said as he laid out the latest iteration of his “Build Back Better” framework, which includes free pre-K and funds for child care and home care. The fate of paid leave is still unclear. https://t.co/k1b61GDGCC',
#      'created_at': '2021-10-28T18:39:49.000Z'},
#     {'conversation_id': '1453792526922440704',
#      'id': '1453792526922440704',
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453377303283699712'}],
#      'text': 'RT @19thnews: Mark your calendar! 🗓️  #The19thLive is back on Nov. 10 to discuss gender equality in the military with women and LGBTQ+ peop…',
#      'created_at': '2021-10-28T18:35:23.000Z',
#      'entities': {'hashtags': [{'start': 38, 'end': 50, 'tag': 'The19thLive'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': '19thnews',
#         'id': '1219278784693768193'}]}},
#     {'conversation_id': '1453782518797197322',
#      'id': '1453782518797197322',
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1451337419085778956'}],
#      'text': 'RT @eramshaw: How does your employer handle miscarriage/pregnancy loss? // "Pregnancy loss is common. Paid time off afterward is not." \n\nht…',
#      'created_at': '2021-10-28T17:55:37.000Z',
#      'entities': {'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'eramshaw',
#         'id': '20626103'}]}},
#     {'conversation_id': '1453775393568133120',
#      'id': '1453775393568133120',
#      'entities': {'annotations': [{'start': 18,
#         'end': 22,
#         'probability': 0.9976,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'mentions': [{'start': 3,
#         'end': 16,
#         'username': 'AmandaBecker',
#         'id': '233985354'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453774822840938499'}],
#      'text': 'RT @AmandaBecker: Biden has multiple people in his agencies who believe this, but has not yet committing to it himself. \nhttps://t.co/XJQ7Z…',
#      'created_at': '2021-10-28T17:27:18.000Z'},
#     {'conversation_id': '1453765244967264257',
#      'id': '1453765244967264257',
#      'entities': {'annotations': [{'start': 63,
#         'end': 67,
#         'probability': 0.9626,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'eramshaw',
#         'id': '20626103'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453758863291785221'}],
#      'text': 'RT @eramshaw: “No one got everything they want, including me,” Biden said as he laid out the latest iteration of his “Build Back Better” fr…',
#      'created_at': '2021-10-28T16:46:58.000Z'},
#     {'conversation_id': '1453751670983340032',
#      'id': '1453751670983340032',
#      'author_id': '1219278784693768193',
#      'text': 'Many gender diverse people have expressed confusion over how the new passports will work. Some fear they will be forced to adopt the new gender markers, even though they will be entirely optional.\nhttps://t.co/0taHg62Ciy',
#      'entities': {'urls': [{'start': 197,
#         'end': 220,
#         'url': 'https://t.co/0taHg62Ciy',
#         'expanded_url': 'https://bit.ly/3vT0Ine',
#         'display_url': 'bit.ly/3vT0Ine'}]},
#      'created_at': '2021-10-28T15:53:02.000Z'},
#     {'conversation_id': '1453748109780164612',
#      'id': '1453748109780164612',
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453745422464274438'}],
#      'text': 'RT @eramshaw: Hey all, please RT — @19thnews is looking for its next great chief financial officer! \n\nhttps://t.co/rvNVgXJTAy\n\nCome work wi…',
#      'entities': {'urls': [{'start': 102,
#         'end': 125,
#         'url': 'https://t.co/rvNVgXJTAy',
#         'expanded_url': 'https://19thnews.org/19th-news-chief-financial-officer-job-posting/',
#         'display_url': '19thnews.org/19th-news-chie…'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'eramshaw',
#         'id': '20626103'},
#        {'start': 35,
#         'end': 44,
#         'username': '19thnews',
#         'id': '1219278784693768193'}]},
#      'created_at': '2021-10-28T15:38:53.000Z'},
#     {'conversation_id': '1453748042994233346',
#      'id': '1453748042994233346',
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453747273704349703'}],
#      'text': "RT @i_oriion: #The19thLive is back y'all 🎉 @marielpadilla_ moderates a great discussion on gender equality in the military. Hear from @Shaw…",
#      'created_at': '2021-10-28T15:38:37.000Z',
#      'entities': {'hashtags': [{'start': 14, 'end': 26, 'tag': 'The19thLive'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'i_oriion',
#         'id': '990261921462079488'},
#        {'start': 43,
#         'end': 58,
#         'username': 'marielpadilla_',
#         'id': '717117312'}]}},
#     {'conversation_id': '1453744126705422350',
#      'id': '1453744126705422350',
#      'entities': {'annotations': [{'start': 2,
#         'end': 10,
#         'probability': 0.7351,
#         'type': 'Organization',
#         'normalized_text': 'Bloomberg'}],
#       'urls': [{'start': 213,
#         'end': 236,
#         'url': 'https://t.co/4bEIxI32ME',
#         'expanded_url': 'https://bloom.bg/3miSAt0',
#         'display_url': 'bloom.bg/3miSAt0'}],
#       'hashtags': [{'start': 193, 'end': 203, 'tag': '19thReads'}],
#       'mentions': [{'start': 208,
#         'end': 211,
#         'username': 'BW',
#         'id': '67358777'}]},
#      'author_id': '1219278784693768193',
#      'text': 'A Bloomberg Businessweek analysis of how 15 global cities rank for career women shows each failing in several ways. No city is doing enough to keep women safe while ending gender inequality. \n\n#19thReads via @BW:\nhttps://t.co/4bEIxI32ME',
#      'created_at': '2021-10-28T15:23:03.000Z'},
#     {'conversation_id': '1453735310014042129',
#      'id': '1453735310014042129',
#      'author_id': '1219278784693768193',
#      'text': 'Scientists are targeting triple-negative cancer, a form of the disease that disproportionately affects Black people and people under 40. https://t.co/95KbvHqna4',
#      'entities': {'urls': [{'start': 137,
#         'end': 160,
#         'url': 'https://t.co/95KbvHqna4',
#         'expanded_url': 'https://19thnews.org/2021/10/trials-begin-on-vaccine-to-prevent-an-aggressive-breast-cancer/?utm_campaign=19th-social&utm_content=scientists_are_targeting_&utm_medium=social&utm_source=twitter',
#         'display_url': '19thnews.org/2021/10/trials…'}]},
#      'created_at': '2021-10-28T14:48:01.000Z'},
#     {'conversation_id': '1453726750689533963',
#      'id': '1453726750689533963',
#      'entities': {'annotations': [{'start': 0,
#         'end': 14,
#         'probability': 0.8625,
#         'type': 'Person',
#         'normalized_text': 'President Biden'}],
#       'urls': [{'start': 251,
#         'end': 274,
#         'url': 'https://t.co/LHwpaxdOCI',
#         'expanded_url': 'https://bit.ly/3nBXQrb',
#         'display_url': 'bit.ly/3nBXQrb'}]},
#      'author_id': '1219278784693768193',
#      'text': 'President Biden is set to announce a new framework for his "Build Back Better" plan that aims to extend the monthly child tax credit, offer universal and free preschool for all 3- and 4-year-olds, and expand free school meals to millions of children. https://t.co/LHwpaxdOCI',
#      'created_at': '2021-10-28T14:14:00.000Z'},
#     {'conversation_id': '1453718947862388737',
#      'id': '1453718947862388737',
#      'entities': {'annotations': [{'start': 7,
#         'end': 19,
#         'probability': 0.5382,
#         'type': 'Organization',
#         'normalized_text': 'Supreme Court'},
#        {'start': 31,
#         'end': 33,
#         'probability': 0.5677,
#         'type': 'Person',
#         'normalized_text': 'Roe'},
#        {'start': 38,
#         'end': 41,
#         'probability': 0.58,
#         'type': 'Person',
#         'normalized_text': 'Wade'}],
#       'urls': [{'start': 167,
#         'end': 190,
#         'url': 'https://t.co/So8FMEqV0Q',
#         'expanded_url': 'https://bit.ly/3bq5mj3',
#         'display_url': 'bit.ly/3bq5mj3'}]},
#      'author_id': '1219278784693768193',
#      'text': 'If the Supreme Court overturns Roe v. Wade, just 13 states could become destinations for people from more than 20 others that would be expected to restrict abortions.\nhttps://t.co/So8FMEqV0Q',
#      'created_at': '2021-10-28T13:43:00.000Z'},
#     {'conversation_id': '1453713917310603268',
#      'id': '1453713917310603268',
#      'entities': {'annotations': [{'start': 26,
#         'end': 38,
#         'probability': 0.6404,
#         'type': 'Person',
#         'normalized_text': 'Amy Klobuchar'},
#        {'start': 113,
#         'end': 130,
#         'probability': 0.8478,
#         'type': 'Organization',
#         'normalized_text': 'Minnesota Democrat'}],
#       'mentions': [{'start': 3,
#         'end': 16,
#         'username': 'AmandaBecker',
#         'id': '233985354'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453666601790808066'}],
#      'text': "RT @AmandaBecker: Senator Amy Klobuchar delayed her routine mammogram — she doesn't want you to do the same. The Minnesota Democrat was dia…",
#      'created_at': '2021-10-28T13:23:01.000Z'},
#     {'conversation_id': '1453713830798893064',
#      'id': '1453713830798893064',
#      'entities': {'annotations': [{'start': 44,
#         'end': 56,
#         'probability': 0.9968,
#         'type': 'Person',
#         'normalized_text': 'Erika Girardi'},
#        {'start': 131,
#         'end': 133,
#         'probability': 0.9653,
#         'type': 'Person',
#         'normalized_text': 'Tom'}],
#       'mentions': [{'start': 3,
#         'end': 19,
#         'username': 'jenniferagerson',
#         'id': '25111161'},
#        {'start': 32, 'end': 37, 'username': 'Andy', 'id': '48100887'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453680014193483779'}],
#      'text': 'RT @jenniferagerson: Last night @Andy asked Erika Girardi about portraying herself as a “victim” this season and not talking about Tom’s al…',
#      'created_at': '2021-10-28T13:22:40.000Z'},
#     {'conversation_id': '1453713767775277058',
#      'id': '1453713767775277058',
#      'entities': {'annotations': [{'start': 21,
#         'end': 33,
#         'probability': 0.4997,
#         'type': 'Organization',
#         'normalized_text': 'Supreme Court'},
#        {'start': 45,
#         'end': 47,
#         'probability': 0.5902,
#         'type': 'Person',
#         'normalized_text': 'Roe'},
#        {'start': 52,
#         'end': 55,
#         'probability': 0.6835,
#         'type': 'Person',
#         'normalized_text': 'Wade'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'eramshaw',
#         'id': '20626103'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453705928792887301'}],
#      'text': 'RT @eramshaw: If the Supreme Court overturns Roe v. Wade, just 13 states could become destinations for people from more than 20 others like…',
#      'created_at': '2021-10-28T13:22:25.000Z'},
#     {'conversation_id': '1453708380045029377',
#      'id': '1453708380045029377',
#      'entities': {'annotations': [{'start': 0,
#         'end': 17,
#         'probability': 0.7543,
#         'type': 'Person',
#         'normalized_text': 'Sen. Amy Klobuchar'}],
#       'urls': [{'start': 201,
#         'end': 224,
#         'url': 'https://t.co/7l2ZCHYQef',
#         'expanded_url': 'https://bit.ly/3BoSdBJ',
#         'display_url': 'bit.ly/3BoSdBJ'}]},
#      'author_id': '1219278784693768193',
#      'text': 'Sen. Amy Klobuchar was treated for breast cancer this year. She is introducing bipartisan legislation that would encourage people to catch up on health screenings, which plummeted during the pandemic. https://t.co/7l2ZCHYQef',
#      'created_at': '2021-10-28T13:01:01.000Z'},
#     {'conversation_id': '1453699066362220544',
#      'id': '1453699066362220544',
#      'entities': {'annotations': [{'start': 44,
#         'end': 64,
#         'probability': 0.4158,
#         'type': 'Organization',
#         'normalized_text': 'New Jersey statehouse'}],
#       'urls': [{'start': 104,
#         'end': 127,
#         'url': 'https://t.co/2g7fiPvrmC',
#         'expanded_url': 'https://bit.ly/3bizHjC',
#         'display_url': 'bit.ly/3bizHjC'}]},
#      'author_id': '1219278784693768193',
#      'text': 'No AAPI women have ever been elected to the New Jersey statehouse. That’s expected to change this year. https://t.co/2g7fiPvrmC',
#      'created_at': '2021-10-28T12:24:00.000Z'},
#     {'conversation_id': '1453571224194404353',
#      'id': '1453571224194404353',
#      'entities': {'annotations': [{'start': 157,
#         'end': 169,
#         'probability': 0.9553,
#         'type': 'Place',
#         'normalized_text': 'United States'}],
#       'urls': [{'start': 235,
#         'end': 258,
#         'url': 'https://t.co/VugCGFPttB',
#         'expanded_url': 'https://bit.ly/3Gm8NFZ',
#         'display_url': 'bit.ly/3Gm8NFZ'}]},
#      'author_id': '1219278784693768193',
#      'text': 'Multiple senators are pushing for an end to the use of electric shock devices on people with disabilities, a tool that is now used by only one school in the United States, where most of the students are Black and Latino boys and men.  https://t.co/VugCGFPttB',
#      'created_at': '2021-10-28T03:56:00.000Z'},
#     {'conversation_id': '1453542048821354499',
#      'id': '1453542048821354499',
#      'author_id': '1219278784693768193',
#      'text': '“Activists have been saying the same thing for years. Leave us alone, leave our bodies alone, let us have autonomy over our own bodies.” https://t.co/Y3AkSZ3w3Q',
#      'entities': {'urls': [{'start': 137,
#         'end': 160,
#         'url': 'https://t.co/Y3AkSZ3w3Q',
#         'expanded_url': 'https://bit.ly/3jL1b6h',
#         'display_url': 'bit.ly/3jL1b6h'}]},
#      'created_at': '2021-10-28T02:00:04.000Z'},
#     {'conversation_id': '1453528694543331329',
#      'id': '1453528694543331329',
#      'entities': {'annotations': [{'start': 0,
#         'end': 14,
#         'probability': 0.8636,
#         'type': 'Person',
#         'normalized_text': 'President Biden'}],
#       'urls': [{'start': 196,
#         'end': 219,
#         'url': 'https://t.co/yjxgLKu6xJ',
#         'expanded_url': 'https://www.nytimes.com/2021/10/27/us/long-covid-disability-benefits.html',
#         'display_url': 'nytimes.com/2021/10/27/us/…'}],
#       'hashtags': [{'start': 171, 'end': 181, 'tag': '19thReads'}],
#       'mentions': [{'start': 186,
#         'end': 194,
#         'username': 'nytimes',
#         'id': '807095'}]},
#      'author_id': '1219278784693768193',
#      'text': 'President Biden has said the government should help people who continue to experience symptoms long after a coronavirus infection. But qualifying remains a major hurdle.\n\n#19thReads via @nytimes: https://t.co/yjxgLKu6xJ',
#      'created_at': '2021-10-28T01:07:00.000Z'},
#     {'conversation_id': '1453504534588891137',
#      'id': '1453504534588891137',
#      'entities': {'annotations': [{'start': 4,
#         'end': 16,
#         'probability': 0.9976,
#         'type': 'Person',
#         'normalized_text': 'Erika Girardi'}],
#       'urls': [{'start': 145,
#         'end': 168,
#         'url': 'https://t.co/IryAxOO3j8',
#         'expanded_url': 'https://19thnews.org/2021/10/erika-girardi-wealth-control-and-abuse/?utm_campaign=19th-social&utm_content=did_erika_girardi_knowthe&utm_medium=social&utm_source=twitter',
#         'display_url': '19thnews.org/2021/10/erika-…'}]},
#      'author_id': '1219278784693768193',
#      'text': 'Did Erika Girardi know?\n\nThe Real Housewife’s divorce sparks questions from fans — and speaks to larger issues of financial control in marriage. https://t.co/IryAxOO3j8',
#      'created_at': '2021-10-27T23:31:00.000Z'},
#     {'conversation_id': '1453503174183096323',
#      'id': '1453503174183096323',
#      'entities': {'annotations': [{'start': 0,
#         'end': 10,
#         'probability': 0.6999,
#         'type': 'Place',
#         'normalized_text': 'White House'},
#        {'start': 77,
#         'end': 81,
#         'probability': 0.8478,
#         'type': 'Person',
#         'normalized_text': 'Biden'},
#        {'start': 230,
#         'end': 234,
#         'probability': 0.8564,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'urls': [{'start': 252,
#         'end': 275,
#         'url': 'https://t.co/t13yfW7eKp',
#         'expanded_url': 'https://19thnews.org/2021/10/intersex-advocates-biden-white-house-meeting/',
#         'display_url': '19thnews.org/2021/10/inters…'}]},
#      'author_id': '1219278784693768193',
#      'text': 'White House officials met virtually with nearly 20 intersex advocates in the Biden administration’s second formal talk with organizers on how to advance intersex rights domestically, and the largest meeting of its kind within the Biden administration. https://t.co/t13yfW7eKp',
#      'created_at': '2021-10-27T23:25:36.000Z'},
#     {'conversation_id': '1453503000463478788',
#      'id': '1453503000463478788',
#      'entities': {'annotations': [{'start': 14,
#         'end': 15,
#         'probability': 0.5137,
#         'type': 'Organization',
#         'normalized_text': 'WH'}],
#       'mentions': [{'start': 3,
#         'end': 12,
#         'username': 'i_oriion',
#         'id': '990261921462079488'}]},
#      'author_id': '1219278784693768193',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453496358460174337'}],
#      'text': 'RT @i_oriion: WH officials met virtually with intersex advocates Tuesday in its 2nd formal talk with organizers on how to advance intersex…',
#      'created_at': '2021-10-27T23:24:54.000Z'}],
#    'meta': {'newest_id': '1453827691141025800',
#     'oldest_id': '1453503000463478788',
#     'result_count': 25}},
#   'ABC': {'data': [{'conversation_id': '1453856123761700879',
#      'entities': {'annotations': [{'start': 0,
#         'end': 2,
#         'probability': 0.8143,
#         'type': 'Place',
#         'normalized_text': 'NYC'}],
#       'urls': [{'start': 131,
#         'end': 154,
#         'url': 'https://t.co/X1He1vNDTE',
#         'expanded_url': 'https://abcn.ws/3BB6g7n',
#         'display_url': 'abcn.ws/3BB6g7n'}]},
#      'id': '1453856123761700879',
#      'author_id': '28785486',
#      'text': "NYC firefighters and other city workers protest outside the mayor's residence as COVID-19 vaccination deadline quickly approaches. https://t.co/X1He1vNDTE",
#      'created_at': '2021-10-28T22:48:05.000Z'},
#     {'conversation_id': '1453852343020269586',
#      'entities': {'annotations': [{'start': 20,
#         'end': 32,
#         'probability': 0.7243,
#         'type': 'Place',
#         'normalized_text': 'Beverly Hills'},
#        {'start': 40,
#         'end': 52,
#         'probability': 0.7443,
#         'type': 'Person',
#         'normalized_text': 'Dorit Kemsley'},
#        {'start': 72,
#         'end': 82,
#         'probability': 0.9413,
#         'type': 'Place',
#         'normalized_text': 'Los Angeles'}],
#       'mentions': [{'start': 114,
#         'end': 118,
#         'username': 'ABC',
#         'id': '28785486'}],
#       'urls': [{'start': 139,
#         'end': 162,
#         'url': 'https://t.co/7LxSWJnYND',
#         'expanded_url': 'https://abcn.ws/3El4kBm',
#         'display_url': 'abcn.ws/3El4kBm',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1453852345327136814/vRoCkpc7?format=jpg&name=orig',
#           'width': 992,
#           'height': 558},
#          {'url': 'https://pbs.twimg.com/news_img/1453852345327136814/vRoCkpc7?format=jpg&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': "'Real Housewives' star robbed at home while her children slept",
#         'description': 'Suspects made off with about $1 million worth of valuables, a source said.',
#         'unwound_url': 'https://www.goodmorningamerica.com/culture/story/real-housewives-star-dorit-kemsley-robbed-home-children-80842388?cid=social_twitter_abcn'}]},
#      'id': '1453852343020269586',
#      'author_id': '28785486',
#      'text': '"Real Housewives of Beverly Hills" star Dorit Kemsley was robbed in her Los Angeles-area home on Wednesday night, @ABC News has confirmed. https://t.co/7LxSWJnYND',
#      'created_at': '2021-10-28T22:33:04.000Z'},
#     {'conversation_id': '1453848804738879492',
#      'id': '1453848804738879492',
#      'author_id': '28785486',
#      'text': 'Patient advocates have been pressing for government negotiation of drug prices. https://t.co/fRPPgKwGYd',
#      'created_at': '2021-10-28T22:19:00.000Z',
#      'entities': {'urls': [{'start': 80,
#         'end': 103,
#         'url': 'https://t.co/fRPPgKwGYd',
#         'expanded_url': 'https://abcn.ws/3mnLxiP',
#         'display_url': 'abcn.ws/3mnLxiP',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1453848807180054539/rYVmyxqN?format=jpg&name=orig',
#           'width': 992,
#           'height': 558},
#          {'url': 'https://pbs.twimg.com/news_img/1453848807180054539/rYVmyxqN?format=jpg&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': "Prescription drug cost relief nixed from Democrats' plan",
#         'description': 'A plan to let the government negotiate lower prescription prices with drug companies will likely not be part of Democrats’ social spending package, the White House said.',
#         'unwound_url': 'https://abcnews.go.com/Politics/prescription-drug-cost-relief-nixed-democrats-plan/story?id=80714742&cid=social_twitter_abcn'}]}},
#     {'conversation_id': '1453846346067107841',
#      'entities': {'annotations': [{'start': 70,
#         'end': 74,
#         'probability': 0.9319,
#         'type': 'Person',
#         'normalized_text': 'Biden'},
#        {'start': 120,
#         'end': 135,
#         'probability': 0.9029,
#         'type': 'Person',
#         'normalized_text': 'Sen. Joe Manchin'}],
#       'mentions': [{'start': 3,
#         'end': 15,
#         'username': 'ABCPolitics',
#         'id': '16815644'},
#        {'start': 28,
#         'end': 41,
#         'username': 'rachelvscott',
#         'id': '88856085'}]},
#      'id': '1453846346067107841',
#      'author_id': '28785486',
#      'text': "RT @ABCPolitics: Pressed by @rachelvscott on where he stands on Pres. Biden's $1.75 trillion social spending framework, Sen. Joe Manchin sa…",
#      'created_at': '2021-10-28T22:09:14.000Z',
#      'referenced_tweets': [{'type': 'retweeted',
#        'id': '1453846302026960897'}]},
#     {'conversation_id': '1453846187182895107',
#      'id': '1453846187182895107',
#      'author_id': '28785486',
#      'text': 'As colder temperatures begin to settle in for many parts of the nation, schools are set to lose critical tools to keep students and staff safe from coronavirus spread, such as extended outdoor time and open windows. https://t.co/wWoXmL1yzs',
#      'created_at': '2021-10-28T22:08:36.000Z',
#      'entities': {'urls': [{'start': 216,
#         'end': 239,
#         'url': 'https://t.co/wWoXmL1yzs',
#         'expanded_url': 'https://abcn.ws/3GzzdUD',
#         'display_url': 'abcn.ws/3GzzdUD'}]}},
#     {'conversation_id': '1453840944730619904',
#      'entities': {'annotations': [{'start': 51,
#         'end': 58,
#         'probability': 0.6828,
#         'type': 'Place',
#         'normalized_text': 'La Palma'},
#        {'start': 62,
#         'end': 73,
#         'probability': 0.2874,
#         'type': 'Place',
#         'normalized_text': 'Cumbre Vieja'},
#        {'start': 90,
#         'end': 103,
#         'probability': 0.7028,
#         'type': 'Place',
#         'normalized_text': 'Canary Islands'}],
#       'urls': [{'start': 106,
#         'end': 129,
#         'url': 'https://t.co/aTXL4YydEq',
#         'expanded_url': 'https://abcn.ws/3jHA9ws',
#         'display_url': 'abcn.ws/3jHA9ws'},
#        {'start': 130,
#         'end': 153,
#         'url': 'https://t.co/iKCih3fUJf',
#         'expanded_url': 'https://twitter.com/ABC/status/1453840944730619904/video/1',
#         'display_url': 'pic.twitter.com/iKCih3fUJf'}]},
#      'id': '1453840944730619904',
#      'author_id': '28785486',
#      'text': 'Spectacular drone footage reveals close-up view of La Palma’s Cumbre Vieja volcano in the Canary Islands. https://t.co/aTXL4YydEq https://t.co/iKCih3fUJf',
#      'created_at': '2021-10-28T21:47:46.000Z',
#      'attachments': {'media_keys': ['13_1453822716813918210']}},
#     {'conversation_id': '1453835474821320710',
#      'entities': {'annotations': [{'start': 130,
#         'end': 133,
#         'probability': 0.9795,
#         'type': 'Place',
#         'normalized_text': 'U.S.'}],
#       'urls': [{'start': 254,
#         'end': 277,
#         'url': 'https://t.co/daqgI33zrL',
#         'expanded_url': 'https://abcn.ws/3nGmHKm',
#         'display_url': 'abcn.ws/3nGmHKm'}]},
#      'id': '1453835474821320710',
#      'author_id': '28785486',
#      'text': 'Border Patrol agents at the center of a controversy stemming from their use of horses to block Haitian migrants from entering the U.S. have not yet been questioned more than a month after the incident took place, according to a law enforcement official. https://t.co/daqgI33zrL',
#      'created_at': '2021-10-28T21:26:02.000Z'},
#     {'conversation_id': '1453829866579709953',
#      'entities': {'annotations': [{'start': 30,
#         'end': 36,
#         'probability': 0.9637,
#         'type': 'Place',
#         'normalized_text': 'Florida'}],
#       'urls': [{'start': 179,
#         'end': 202,
#         'url': 'https://t.co/1wImQBtscT',
#         'expanded_url': 'https://abcn.ws/3jHIGPR',
#         'display_url': 'abcn.ws/3jHIGPR'}]},
#      'id': '1453829866579709953',
#      'author_id': '28785486',
#      'text': 'A coalition of engineers says Florida should consider requiring high-rise buildings near the coast to undergo safety inspections every 20 years with follow-ups every seven years. https://t.co/1wImQBtscT',
#      'created_at': '2021-10-28T21:03:45.000Z'},
#     {'conversation_id': '1453825705633058818',
#      'entities': {'annotations': [{'start': 115,
#         'end': 122,
#         'probability': 0.9701,
#         'type': 'Place',
#         'normalized_text': 'La Palma'},
#        {'start': 195,
#         'end': 206,
#         'probability': 0.6731,
#         'type': 'Place',
#         'normalized_text': 'Cumbre Vieja'}],
#       'urls': [{'start': 217,
#         'end': 240,
#         'url': 'https://t.co/dE4J8kmhQm',
#         'expanded_url': 'https://abcn.ws/3mo1S7h',
#         'display_url': 'abcn.ws/3mo1S7h'},
#        {'start': 241,
#         'end': 264,
#         'url': 'https://t.co/n3ANsjDJx8',
#         'expanded_url': 'https://twitter.com/ABC/status/1453825705633058818/video/1',
#         'display_url': 'pic.twitter.com/n3ANsjDJx8'}]},
#      'id': '1453825705633058818',
#      'author_id': '28785486',
#      'text': 'Members of the Spanish military used shovels, brooms and wheelbarrows to remove ash from rooftops on the island of La Palma, clearing them to avoid building collapses, following eruptions of the Cumbre Vieja volcano. https://t.co/dE4J8kmhQm https://t.co/n3ANsjDJx8',
#      'created_at': '2021-10-28T20:47:13.000Z',
#      'attachments': {'media_keys': ['13_1453819246224547840']}},
#     {'conversation_id': '1453821100295606272',
#      'entities': {'annotations': [{'start': 17,
#         'end': 28,
#         'probability': 0.4823,
#         'type': 'Place',
#         'normalized_text': 'New York Gov'},
#        {'start': 31,
#         'end': 42,
#         'probability': 0.9957,
#         'type': 'Person',
#         'normalized_text': 'Andrew Cuomo'},
#        {'start': 122,
#         'end': 148,
#         'probability': 0.806,
#         'type': 'Organization',
#         'normalized_text': 'New York State Court System'}],
#       'urls': [{'start': 151,
#         'end': 174,
#         'url': 'https://t.co/fq2jn3e1lW',
#         'expanded_url': 'https://abcn.ws/3nAkNet',
#         'display_url': 'abcn.ws/3nAkNet'}]},
#      'id': '1453821100295606272',
#      'author_id': '28785486',
#      'text': 'BREAKING: Former New York Gov. Andrew Cuomo has been charged with misdemeanor sex crime, according to a spokesman for the New York State Court System. https://t.co/fq2jn3e1lW',
#      'created_at': '2021-10-28T20:28:55.000Z'},
#     {'conversation_id': '1453819009791635462',
#      'entities': {'annotations': [{'start': 100,
#         'end': 124,
#         'probability': 0.9739,
#         'type': 'Place',
#         'normalized_text': 'Yellowstone National Park'}],
#       'urls': [{'start': 151,
#         'end': 174,
#         'url': 'https://t.co/GlbaLrV9sJ',
#         'expanded_url': 'https://abcn.ws/3jLW4Ti',
#         'display_url': 'abcn.ws/3jLW4Ti'},
#        {'start': 175,
#         'end': 198,
#         'url': 'https://t.co/HdSo8MigKF',
#         'expanded_url': 'https://twitter.com/ABC/status/1453819009791635462/video/1',
#         'display_url': 'pic.twitter.com/HdSo8MigKF'}]},
#      'id': '1453819009791635462',
#      'author_id': '28785486',
#      'text': "If you're going to get caught in a traffic jam, getting to see a herd of bison crossing a bridge in Yellowstone National Park is a pretty good reason. https://t.co/GlbaLrV9sJ https://t.co/HdSo8MigKF",
#      'created_at': '2021-10-28T20:20:37.000Z',
#      'attachments': {'media_keys': ['13_1453732695628943361']}},
#     {'conversation_id': '1453816857803231241',
#      'id': '1453816857803231241',
#      'author_id': '28785486',
#      'text': 'A German electrician has gone on trial accused of murder in the death of one man, and of mutilating several others by performing illegal operations on their genitals. https://t.co/hwtSrFXnP6',
#      'created_at': '2021-10-28T20:12:04.000Z',
#      'entities': {'urls': [{'start': 167,
#         'end': 190,
#         'url': 'https://t.co/hwtSrFXnP6',
#         'expanded_url': 'https://abcn.ws/2XSyZXe',
#         'display_url': 'abcn.ws/2XSyZXe'}]}},
#     {'conversation_id': '1453811693881004033',
#      'entities': {'annotations': [{'start': 51,
#         'end': 54,
#         'probability': 0.9645,
#         'type': 'Place',
#         'normalized_text': 'U.S.'}],
#       'urls': [{'start': 87,
#         'end': 110,
#         'url': 'https://t.co/AQz4HTTzrq',
#         'expanded_url': 'https://abcn.ws/3nBMxiT',
#         'display_url': 'abcn.ws/3nBMxiT'}]},
#      'id': '1453811693881004033',
#      'author_id': '28785486',
#      'text': "Dozens of recall campaigns are underway across the U.S. ahead of next week's election. https://t.co/AQz4HTTzrq",
#      'created_at': '2021-10-28T19:51:32.000Z'},
#     {'conversation_id': '1453807594682920961',
#      'id': '1453807594682920961',
#      'author_id': '28785486',
#      'text': 'Experts said legislatures are doing the work in setting the landscape on guns. https://t.co/vdjCK99WGb',
#      'created_at': '2021-10-28T19:35:15.000Z',
#      'entities': {'urls': [{'start': 79,
#         'end': 102,
#         'url': 'https://t.co/vdjCK99WGb',
#         'expanded_url': 'https://abcn.ws/3nGaLby',
#         'display_url': 'abcn.ws/3nGaLby'}]}},
#     {'conversation_id': '1453793954047172618',
#      'entities': {'annotations': [{'start': 0,
#         'end': 7,
#         'probability': 0.9436,
#         'type': 'Organization',
#         'normalized_text': 'Facebook'},
#        {'start': 38,
#         'end': 51,
#         'probability': 0.6477,
#         'type': 'Organization',
#         'normalized_text': 'Silicon Valley'}],
#       'urls': [{'start': 147,
#         'end': 170,
#         'url': 'https://t.co/hctRupbqmP',
#         'expanded_url': 'https://abcn.ws/3jMyANH',
#         'display_url': 'abcn.ws/3jMyANH'},
#        {'start': 171,
#         'end': 194,
#         'url': 'https://t.co/TrfavC8Xd3',
#         'expanded_url': 'https://twitter.com/ABC/status/1453804152451059712/video/1',
#         'display_url': 'pic.twitter.com/TrfavC8Xd3'}]},
#      'id': '1453804152451059712',
#      'author_id': '28785486',
#      'text': 'Facebook unveils new logo outside its Silicon Valley headquarters as the company rebrands to "Meta" amid mounting controversies for the tech firm. https://t.co/hctRupbqmP https://t.co/TrfavC8Xd3',
#      'created_at': '2021-10-28T19:21:34.000Z',
#      'referenced_tweets': [{'type': 'replied_to',
#        'id': '1453793954047172618'}],
#      'attachments': {'media_keys': ['7_1453803971244552195']}},
#     {'conversation_id': '1453803459183001605',
#      'entities': {'annotations': [{'start': 0,
#         'end': 11,
#         'probability': 0.5126,
#         'type': 'Place',
#         'normalized_text': 'North Korean'},
#        {'start': 20,
#         'end': 30,
#         'probability': 0.9828,
#         'type': 'Person',
#         'normalized_text': 'Kim Jong Un'},
#        {'start': 102,
#         'end': 113,
#         'probability': 0.4531,
#         'type': 'Place',
#         'normalized_text': 'South Korean'}],
#       'urls': [{'start': 205,
#         'end': 228,
#         'url': 'https://t.co/9WQ3K75gsa',
#         'expanded_url': 'https://abcn.ws/2Zwhtcn',
#         'display_url': 'abcn.ws/2Zwhtcn'}]},
#      'id': '1453803459183001605',
#      'author_id': '28785486',
#      'text': 'North Korean leader Kim Jong Un has seemed to have lost 44 pounds in the past two years, according to South Korean lawmakers who were briefed by the country’s intelligence agency in a closed-door meeting. https://t.co/9WQ3K75gsa',
#      'created_at': '2021-10-28T19:18:49.000Z'},
#     {'conversation_id': '1453798242945220618',
#      'entities': {'annotations': [{'start': 0,
#         'end': 18,
#         'probability': 0.8449,
#         'type': 'Person',
#         'normalized_text': 'Sen. Bernie Sanders'},
#        {'start': 25,
#         'end': 28,
#         'probability': 0.6053,
#         'type': 'Person',
#         'normalized_text': 'Pres'},
#        {'start': 31,
#         'end': 35,
#         'probability': 0.8352,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'urls': [{'start': 256,
#         'end': 279,
#         'url': 'https://t.co/47FAYBnGmb',
#         'expanded_url': 'https://abcn.ws/2XRTXp8',
#         'display_url': 'abcn.ws/2XRTXp8'},
#        {'start': 280,
#         'end': 303,
#         'url': 'https://t.co/S94k6aCULm',
#         'expanded_url': 'https://twitter.com/ABC/status/1453798242945220618/video/1',
#         'display_url': 'pic.twitter.com/S94k6aCULm'}]},
#      'id': '1453798242945220618',
#      'author_id': '28785486',
#      'text': 'Sen. Bernie Sanders says Pres. Biden’s economic framework is a “major step forward” but has some “major gaps in it.” \n\n“The American people are very, very clear that they’re sick and tired of paying the highest prices in the world for prescription drugs." https://t.co/47FAYBnGmb https://t.co/S94k6aCULm',
#      'created_at': '2021-10-28T18:58:06.000Z',
#      'attachments': {'media_keys': ['13_1453797977298976770']}},
#     {'conversation_id': '1453795109313695746',
#      'id': '1453795109313695746',
#      'author_id': '28785486',
#      'text': 'RT @ABCPolitics: “It’s remarkable. It’s remarkable in that it’s a big vision, bigger vision than we’ve seen in a very long time, maybe dati…',
#      'created_at': '2021-10-28T18:45:38.000Z',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1453792066539081732'}],
#      'entities': {'mentions': [{'start': 3,
#         'end': 15,
#         'username': 'ABCPolitics',
#         'id': '16815644'}]}},
#     {'conversation_id': '1453793954047172618',
#      'entities': {'annotations': [{'start': 81,
#         'end': 88,
#         'probability': 0.9516,
#         'type': 'Organization',
#         'normalized_text': 'Facebook'},
#        {'start': 94,
#         'end': 108,
#         'probability': 0.9801,
#         'type': 'Person',
#         'normalized_text': 'Mark Zuckerberg'}],
#       'urls': [{'start': 209,
#         'end': 232,
#         'url': 'https://t.co/CcI4n0i2pi',
#         'expanded_url': 'https://abcn.ws/30ZQ1Uv',
#         'display_url': 'abcn.ws/30ZQ1Uv'}]},
#      'id': '1453793954047172618',
#      'author_id': '28785486',
#      'text': 'BREAKING: In the shadow of mounting controversies for his beleaguered tech firm, Facebook CEO Mark Zuckerberg announced that the name of his tech giant will be changed to "Meta" to reflect the shifting focus. https://t.co/CcI4n0i2pi',
#      'created_at': '2021-10-28T18:41:03.000Z'},
#     {'conversation_id': '1453790946601078786',
#      'entities': {'annotations': [{'start': 0,
#         'end': 3,
#         'probability': 0.9496,
#         'type': 'Place',
#         'normalized_text': 'U.S.'},
#        {'start': 56,
#         'end': 60,
#         'probability': 0.996,
#         'type': 'Place',
#         'normalized_text': 'India'}],
#       'urls': [{'start': 118,
#         'end': 141,
#         'url': 'https://t.co/NZN0oID3d3',
#         'expanded_url': 'https://abcn.ws/3CBfeT2',
#         'display_url': 'abcn.ws/3CBfeT2'}]},
#      'id': '1453790946601078786',
#      'author_id': '28785486',
#      'text': 'U.S. authorities have returned about 250 antiquities to India in a long-running investigation of a stolen art scheme. https://t.co/NZN0oID3d3',
#      'created_at': '2021-10-28T18:29:06.000Z'},
#     {'conversation_id': '1453788187785146389',
#      'entities': {'annotations': [{'start': 104,
#         'end': 120,
#         'probability': 0.9674,
#         'type': 'Person',
#         'normalized_text': 'David Constantine'},
#        {'start': 127,
#         'end': 135,
#         'probability': 0.4704,
#         'type': 'Organization',
#         'normalized_text': 'The Queen'}],
#       'urls': [{'start': 169,
#         'end': 192,
#         'url': 'https://t.co/jFOhEe1vt7',
#         'expanded_url': 'https://gma.abc/3CtFUoT',
#         'display_url': 'gma.abc/3CtFUoT'},
#        {'start': 193,
#         'end': 216,
#         'url': 'https://t.co/G1pqgDwwlL',
#         'expanded_url': 'https://twitter.com/ABC/status/1453788187785146389/video/1',
#         'display_url': 'pic.twitter.com/G1pqgDwwlL'}]},
#      'id': '1453788187785146389',
#      'author_id': '28785486',
#      'text': "After being hospitalized and later canceling her trip to the global climate summit, the queen presented David Constantine with The Queen's Gold Medal for Poetry online. https://t.co/jFOhEe1vt7 https://t.co/G1pqgDwwlL",
#      'created_at': '2021-10-28T18:18:08.000Z',
#      'attachments': {'media_keys': ['13_1453786605412626439']}},
#     {'conversation_id': '1453785801268109318',
#      'entities': {'annotations': [{'start': 46,
#         'end': 50,
#         'probability': 0.8709,
#         'type': 'Person',
#         'normalized_text': 'Biden'},
#        {'start': 121,
#         'end': 129,
#         'probability': 0.7909,
#         'type': 'Place',
#         'normalized_text': 'U.S. West'}],
#       'urls': [{'start': 132,
#         'end': 155,
#         'url': 'https://t.co/OjfBQDNW4A',
#         'expanded_url': 'https://abcn.ws/3GH7emj',
#         'display_url': 'abcn.ws/3GH7emj'}]},
#      'id': '1453785801268109318',
#      'author_id': '28785486',
#      'text': 'A group of Democratic lawmakers is urging the Biden administration to enact emergency protections for gray wolves in the U.S. West. https://t.co/OjfBQDNW4A',
#      'created_at': '2021-10-28T18:08:39.000Z'},
#     {'conversation_id': '1453784474488033283',
#      'entities': {'annotations': [{'start': 52,
#         'end': 55,
#         'probability': 0.6398,
#         'type': 'Person',
#         'normalized_text': 'Pres'},
#        {'start': 58,
#         'end': 66,
#         'probability': 0.9941,
#         'type': 'Person',
#         'normalized_text': 'Joe Biden'}],
#       'mentions': [{'start': 1,
#         'end': 11,
#         'username': 'DavidMuir',
#         'id': '56223278'}],
#       'urls': [{'start': 90,
#         'end': 113,
#         'url': 'https://t.co/0R5haWThJD',
#         'expanded_url': 'http://abcn.ws/2ZHEYyW',
#         'display_url': 'abcn.ws/2ZHEYyW'},
#        {'start': 114,
#         'end': 137,
#         'url': 'https://t.co/JHrbUml9Z3',
#         'expanded_url': 'https://twitter.com/ABC/status/1453784474488033283/video/1',
#         'display_url': 'pic.twitter.com/JHrbUml9Z3'}]},
#      'id': '1453784474488033283',
#      'author_id': '28785486',
#      'text': ".@DavidMuir breaks down what you need to know about Pres. Joe Biden's economic framework. https://t.co/0R5haWThJD https://t.co/JHrbUml9Z3",
#      'created_at': '2021-10-28T18:03:23.000Z',
#      'attachments': {'media_keys': ['13_1453777955390435339']}},
#     {'conversation_id': '1453781157095616512',
#      'entities': {'annotations': [{'start': 59,
#         'end': 70,
#         'probability': 0.9985,
#         'type': 'Person',
#         'normalized_text': 'Alec Baldwin'},
#        {'start': 125,
#         'end': 139,
#         'probability': 0.6154,
#         'type': 'Person',
#         'normalized_text': 'Ireland Baldwin'}],
#       'urls': [{'start': 166,
#         'end': 189,
#         'url': 'https://t.co/LhL3GPWsJl',
#         'expanded_url': 'https://abcn.ws/3CqTtFw',
#         'display_url': 'abcn.ws/3CqTtFw'}]},
#      'id': '1453781157095616512',
#      'author_id': '28785486',
#      'text': 'Following last week\'s deadly accidental shooting involving Alec Baldwin on the set of the film "Rust," the actor\'s daughter, Ireland Baldwin, has broken her silence. https://t.co/LhL3GPWsJl',
#      'created_at': '2021-10-28T17:50:12.000Z'},
#     {'conversation_id': '1453776374389518346',
#      'entities': {'annotations': [{'start': 83,
#         'end': 88,
#         'probability': 0.3162,
#         'type': 'Organization',
#         'normalized_text': 'TikTok'}],
#       'urls': [{'start': 134,
#         'end': 157,
#         'url': 'https://t.co/ZQov5sTkb7',
#         'expanded_url': 'https://abcn.ws/3mmMub3',
#         'display_url': 'abcn.ws/3mmMub3'},
#        {'start': 158,
#         'end': 181,
#         'url': 'https://t.co/x4ujplI2GD',
#         'expanded_url': 'https://twitter.com/ABC/status/1453776374389518346/photo/1',
#         'display_url': 'pic.twitter.com/x4ujplI2GD'}]},
#      'id': '1453776374389518346',
#      'author_id': '28785486',
#      'text': 'Young people everywhere are giving themselves lip filler using DIY methods seen on TikTok, and medical professionals want it to stop. https://t.co/ZQov5sTkb7 https://t.co/x4ujplI2GD',
#      'created_at': '2021-10-28T17:31:12.000Z',
#      'attachments': {'media_keys': ['3_1453776372300668928']}},
#     {'conversation_id': '1453772212561924104',
#      'entities': {'annotations': [{'start': 91,
#         'end': 94,
#         'probability': 0.9816,
#         'type': 'Place',
#         'normalized_text': 'U.S.'},
#        {'start': 185,
#         'end': 188,
#         'probability': 0.9646,
#         'type': 'Place',
#         'normalized_text': 'U.S.'}],
#       'mentions': [{'start': 1,
#         'end': 5,
#         'username': 'ABC',
#         'id': '28785486'}],
#       'urls': [{'start': 236,
#         'end': 259,
#         'url': 'https://t.co/D3kVtxcnqe',
#         'expanded_url': 'https://abcn.ws/3nzNvMB',
#         'display_url': 'abcn.ws/3nzNvMB'},
#        {'start': 260,
#         'end': 283,
#         'url': 'https://t.co/eG8FbW6XPB',
#         'expanded_url': 'https://twitter.com/ABC/status/1453772212561924104/photo/1',
#         'display_url': 'pic.twitter.com/eG8FbW6XPB'}]},
#      'id': '1453772212561924104',
#      'author_id': '28785486',
#      'text': '.@ABC News has launched an interactive tool to track reported gun-related incidents in the U.S. as part of "Rethinking Gun Violence"—a series examining the level of gun violence in the U.S. and what can be done about it.\n\nFollow along: https://t.co/D3kVtxcnqe https://t.co/eG8FbW6XPB',
#      'created_at': '2021-10-28T17:14:39.000Z',
#      'attachments': {'media_keys': ['3_1453772211026804737']}},
#     {'conversation_id': '1453770493031505920',
#      'entities': {'annotations': [{'start': 4,
#         'end': 8,
#         'probability': 0.952,
#         'type': 'Organization',
#         'normalized_text': 'NAACP'},
#        {'start': 35,
#         'end': 37,
#         'probability': 0.9813,
#         'type': 'Organization',
#         'normalized_text': 'NBA'},
#        {'start': 40,
#         'end': 43,
#         'probability': 0.9808,
#         'type': 'Organization',
#         'normalized_text': 'WNBA'},
#        {'start': 46,
#         'end': 48,
#         'probability': 0.9985,
#         'type': 'Organization',
#         'normalized_text': 'NFL'},
#        {'start': 51,
#         'end': 53,
#         'probability': 0.9992,
#         'type': 'Organization',
#         'normalized_text': 'NHL'},
#        {'start': 59,
#         'end': 61,
#         'probability': 0.9954,
#         'type': 'Organization',
#         'normalized_text': 'MLB'},
#        {'start': 101,
#         'end': 105,
#         'probability': 0.9136,
#         'type': 'Place',
#         'normalized_text': 'Texas'}],
#       'urls': [{'start': 185,
#         'end': 208,
#         'url': 'https://t.co/qed5FvsgR1',
#         'expanded_url': 'https://abcn.ws/2ZrK95K',
#         'display_url': 'abcn.ws/2ZrK95K'},
#        {'start': 209,
#         'end': 232,
#         'url': 'https://t.co/qtOanvIiZ3',
#         'expanded_url': 'https://twitter.com/ABC/status/1453770493031505920/photo/1',
#         'display_url': 'pic.twitter.com/qtOanvIiZ3'}]},
#      'id': '1453770493031505920',
#      'author_id': '28785486',
#      'text': 'The NAACP called on members of the NBA, WNBA, NFL, NHL and MLB to consider not signing with teams in Texas as a protest against several controversial laws passed recently in the state. https://t.co/qed5FvsgR1 https://t.co/qtOanvIiZ3',
#      'created_at': '2021-10-28T17:07:49.000Z',
#      'attachments': {'media_keys': ['3_1453770488803692549']}},
#     {'conversation_id': '1453766226782605321',
#      'id': '1453766226782605321',
#      'author_id': '28785486',
#      'text': 'Photo of toilet paper and Cheez-Its becomes lesson on supporting someone after miscarriage. https://t.co/81ygJS5WNW https://t.co/sC7F9iVuaR',
# ...
#      'created_at': '2021-11-02T12:30:05.000Z'}],
#    'meta': {'newest_id': '1455629270571683842',
#     'oldest_id': '1455512535357087751',
#     'result_count': 12}},
#   'AmerIndependent': {'data': [{'entities': {'annotations': [{'start': 132,
#         'end': 136,
#         'probability': 0.9192,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'urls': [{'start': 159,
#         'end': 182,
#         'url': 'https://t.co/arf1IXU5zg',
#         'expanded_url': 'https://buff.ly/3qfoPfl',
#         'display_url': 'buff.ly/3qfoPfl'}]},
#      'text': "According to recent polls, the people truly want investments in:\n♻️ Clean energy\n🍼 Caregiving\n🏥 Health care\n🏠 Housing\n💼 Jobs\n🌟 Biden's Build Back Better plan\n\nhttps://t.co/arf1IXU5zg",
#      'id': '1455668545002606605',
#      'conversation_id': '1455668545002606605',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T22:50:00.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 13,
#         'probability': 0.8143,
#         'type': 'Place',
#         'normalized_text': 'Loudoun County'}],
#       'urls': [{'start': 199,
#         'end': 222,
#         'url': 'https://t.co/krYOHBeFcl',
#         'expanded_url': 'https://buff.ly/3bwEApw',
#         'display_url': 'buff.ly/3bwEApw'}]},
#      'text': "Loudoun County's top attorney is being targeted by a right-wing disinformation campaign, which hinges on a debunked sexual assault case.\n\nEven worse, the false claims have been boosted by Youngkin. 😞https://t.co/krYOHBeFcl",
#      'id': '1455659741183631364',
#      'conversation_id': '1455659741183631364',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T22:15:01.000Z'},
#     {'entities': {'mentions': [{'start': 78,
#         'end': 92,
#         'username': 'thatcaseyquin',
#         'id': '163641749'}],
#       'urls': [{'start': 94,
#         'end': 117,
#         'url': 'https://t.co/vhsoJTVmpf',
#         'expanded_url': 'https://buff.ly/3BLgYbu',
#         'display_url': 'buff.ly/3BLgYbu'}]},
#      'text': 'Federal agencies clear way for LGBTQ people to access survivors benefits \n\nby @thatcaseyquin \nhttps://t.co/vhsoJTVmpf',
#      'id': '1455649674329788418',
#      'conversation_id': '1455649674329788418',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T21:35:01.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 10,
#         'probability': 0.8068,
#         'type': 'Organization',
#         'normalized_text': 'Republicans'}],
#       'mentions': [{'start': 68,
#         'end': 77,
#         'username': 'jeisrael',
#         'id': '25337798'}],
#       'urls': [{'start': 79,
#         'end': 102,
#         'url': 'https://t.co/8bmVJf6q1B',
#         'expanded_url': 'https://buff.ly/3GIRRcW',
#         'display_url': 'buff.ly/3GIRRcW',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1455634582930444297/L03PkvD3?format=jpg&name=orig',
#           'width': 1024,
#           'height': 681},
#          {'url': 'https://pbs.twimg.com/news_img/1455634582930444297/L03PkvD3?format=jpg&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': 'Republicans try new bad-faith attack on Build Back Better plan',
#         'description': "Congressional Republicans are mocking the concept of 'tree equity,' which would fund a wave of new jobs and plant trees in neighborhoods without any.",
#         'unwound_url': 'https://americanindependent.com/gop-republicans-congress-joe-biden-build-back-better-plant-more-trees-tree-equity/?utm_content=buffere334a&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer'}]},
#      'text': 'Republicans try new bad-faith attack on Build Back Better plan \n\nby @jeisrael \nhttps://t.co/8bmVJf6q1B',
#      'id': '1455634572306157570',
#      'conversation_id': '1455634572306157570',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T20:35:01.000Z'},
#     {'entities': {'annotations': [{'start': 43,
#         'end': 45,
#         'probability': 0.9372,
#         'type': 'Organization',
#         'normalized_text': 'GOP'}],
#       'urls': [{'start': 125,
#         'end': 148,
#         'url': 'https://t.co/x8qUqzKGzh',
#         'expanded_url': 'https://buff.ly/3mD5tyv',
#         'display_url': 'buff.ly/3mD5tyv'}]},
#      'text': 'Before the ballots have even been counted, GOP officials and conservative media pundits have started crying "voter fraud." 🙄 https://t.co/x8qUqzKGzh',
#      'id': '1455629538696773633',
#      'conversation_id': '1455629538696773633',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T20:15:00.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 7,
#         'probability': 0.9661,
#         'type': 'Organization',
#         'normalized_text': 'Fox News'}],
#       'mentions': [{'start': 84,
#         'end': 92,
#         'username': 'owillis',
#         'id': '3497941'}],
#       'urls': [{'start': 94,
#         'end': 117,
#         'url': 'https://t.co/LZj7HhcaMq',
#         'expanded_url': 'https://buff.ly/3bQ0Tqt',
#         'display_url': 'buff.ly/3bQ0Tqt'}]},
#      'text': 'Fox News falsely claims police reform would stop cops from responding to crime \n\nby @owillis \nhttps://t.co/LZj7HhcaMq',
#      'id': '1455621233568096258',
#      'conversation_id': '1455621233568096258',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T19:42:00.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 10,
#         'probability': 0.878,
#         'type': 'Organization',
#         'normalized_text': 'Republicans'},
#        {'start': 61,
#         'end': 74,
#         'probability': 0.6132,
#         'type': 'Place',
#         'normalized_text': 'Loudoun County'},
#        {'start': 125,
#         'end': 136,
#         'probability': 0.9362,
#         'type': 'Person',
#         'normalized_text': 'Buta Biberaj'},
#        {'start': 190,
#         'end': 197,
#         'probability': 0.9969,
#         'type': 'Place',
#         'normalized_text': 'Virginia'}],
#       'urls': [{'start': 200,
#         'end': 223,
#         'url': 'https://t.co/XRGO2lH92U',
#         'expanded_url': 'https://buff.ly/2ZVaeKZ',
#         'display_url': 'buff.ly/2ZVaeKZ'}]},
#      'text': 'Republicans are relying on a recent sexual assault case in a Loudoun County school to fuel a disinformation campaign against Buta Biberaj, the first Muslim to be elected to public office in Virginia.\nhttps://t.co/XRGO2lH92U',
#      'id': '1455616956795658251',
#      'conversation_id': '1455616956795658251',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T19:25:01.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 4,
#         'probability': 0.9589,
#         'type': 'Person',
#         'normalized_text': 'Biden'}],
#       'mentions': [{'start': 74,
#         'end': 83,
#         'username': 'jeisrael',
#         'id': '25337798'}],
#       'urls': [{'start': 85,
#         'end': 108,
#         'url': 'https://t.co/uJ0SljKIZh',
#         'expanded_url': 'https://buff.ly/3BFIU0j',
#         'display_url': 'buff.ly/3BFIU0j'}]},
#      'text': "Biden's $1.75 trillion Build Back Better plan is popular with voters \n\nby @jeisrael \nhttps://t.co/uJ0SljKIZh",
#      'id': '1455611765690150913',
#      'conversation_id': '1455611765690150913',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T19:04:23.000Z'},
#     {'entities': {'annotations': [{'start': 27,
#         'end': 34,
#         'probability': 0.8575,
#         'type': 'Person',
#         'normalized_text': 'Youngkin'}],
#       'mentions': [{'start': 3,
#         'end': 19,
#         'username': 'AmerIndependent',
#         'id': '2467720274'}]},
#      'text': 'RT @AmerIndependent: While Youngkin has spent the past few months hiding his extreme views, our team has been reporting on his true motives…',
#      'referenced_tweets': [{'type': 'retweeted', 'id': '1455262612674039815'}],
#      'id': '1455586859413909511',
#      'conversation_id': '1455586859413909511',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T17:25:25.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 10,
#         'probability': 0.8152,
#         'type': 'Organization',
#         'normalized_text': 'Republicans'},
#        {'start': 68,
#         'end': 75,
#         'probability': 0.7944,
#         'type': 'Place',
#         'normalized_text': 'Virginia'}],
#       'mentions': [{'start': 92,
#         'end': 102,
#         'username': 'CahnEmily',
#         'id': '18825339'}],
#       'urls': [{'start': 104,
#         'end': 127,
#         'url': 'https://t.co/NvoUWBnbOD',
#         'expanded_url': 'https://buff.ly/2ZVbo9j',
#         'display_url': 'buff.ly/2ZVbo9j'}]},
#      'text': 'Republicans are already making baseless claims about fraud ahead of Virginia elections \n\nby @CahnEmily \nhttps://t.co/NvoUWBnbOD',
#      'id': '1455577948753367044',
#      'conversation_id': '1455577948753367044',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T16:50:00.000Z'},
#     {'entities': {'mentions': [{'start': 94,
#         'end': 106,
#         'username': 'j0shaxelrod',
#         'id': '2233714004'}],
#       'urls': [{'start': 108,
#         'end': 131,
#         'url': 'https://t.co/qGpg9vDKPW',
#         'expanded_url': 'https://buff.ly/3GHpRWZ',
#         'display_url': 'buff.ly/3GHpRWZ',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1455562743541641217/h9DIfWxF?format=jpg&name=orig',
#           'width': 1024,
#           'height': 768},
#          {'url': 'https://pbs.twimg.com/news_img/1455562743541641217/h9DIfWxF?format=jpg&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': 'White supremacists target Muslim prosecutor over false claim she covered up assault case',
#         'description': "Loudoun County, Virginia, Commonwealth's Attorney Buta Biberaj has received death threats over her handling of the case.",
#         'unwound_url': 'https://americanindependent.com/buta-biberaj-white-supremacists-virginia/?utm_content=buffer1c286&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer'}]},
#      'text': 'White supremacists target Muslim prosecutor over false claim she covered up assault case \n\nby @j0shaxelrod \nhttps://t.co/qGpg9vDKPW',
#      'id': '1455562732716105728',
#      'conversation_id': '1455562732716105728',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T15:49:33.000Z'},
#     {'entities': {'mentions': [{'start': 28,
#         'end': 38,
#         'username': 'claytoonz',
#         'id': '24223060'}],
#       'urls': [{'start': 40,
#         'end': 63,
#         'url': 'https://t.co/TFLSkLCUdB',
#         'expanded_url': 'https://buff.ly/3CD1reQ',
#         'display_url': 'buff.ly/3CD1reQ'}]},
#      'text': "Cartoon: Let's go who? \n\nby @claytoonz \nhttps://t.co/TFLSkLCUdB",
#      'id': '1455539348368207881',
#      'conversation_id': '1455539348368207881',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T14:16:37.000Z'},
#     {'entities': {'annotations': [{'start': 7,
#         'end': 17,
#         'probability': 0.7849,
#         'type': 'Organization',
#         'normalized_text': 'Republicans'}],
#       'mentions': [{'start': 86,
#         'end': 97,
#         'username': 'WhiteHouse',
#         'id': '1323730225067339784'}],
#       'urls': [{'start': 139,
#         'end': 162,
#         'url': 'https://t.co/BtXADONqOP',
#         'expanded_url': 'https://buff.ly/3w9Rvaf',
#         'display_url': 'buff.ly/3w9Rvaf',
#         'images': [{'url': 'https://pbs.twimg.com/news_img/1455264856672804873/jjth0_qa?format=jpg&name=orig',
#           'width': 1024,
#           'height': 683},
#          {'url': 'https://pbs.twimg.com/news_img/1455264856672804873/jjth0_qa?format=jpg&name=150x150',
#           'width': 150,
#           'height': 150}],
#         'status': 200,
#         'title': 'Republicans blame Biden administration for stopping drugs from entering the US',
#         'description': "The Biden administration is seizing illegal drugs at the U.S. border, and GOP lawmakers think that's a bad thing.",
#         'unwound_url': 'https://americanindependent.com/republicans-joe-biden-customs-border-patrol-opioids-fentanyl-seizures/?utm_content=buffer3c159&utm_medium=social&utm_source=twitter.com&utm_campaign=buffer'}]},
#      'text': '"Wait, Republicans are now attacking us for stopping fentanyl trafficking?" asked the @WhiteHouse deputy press secretary. \n\nApparently so!\nhttps://t.co/BtXADONqOP',
#      'id': '1455492637407027203',
#      'conversation_id': '1455492637407027203',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T11:11:01.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 6,
#         'probability': 0.4564,
#         'type': 'Person',
#         'normalized_text': 'Boebert'},
#        {'start': 116,
#         'end': 123,
#         'probability': 0.9295,
#         'type': 'Place',
#         'normalized_text': 'New York'}],
#       'urls': [{'start': 181,
#         'end': 204,
#         'url': 'https://t.co/WZti3ubfng',
#         'expanded_url': 'https://buff.ly/3nN0tq7',
#         'display_url': 'buff.ly/3nN0tq7'}]},
#      'text': 'Boebert named the proposal the "Stop AOC Act," an apparent reference to Democratic Rep. Alexandria Ocasio-Cortez of New York, after she championed the funeral assistance funds. 🤔 \n\nhttps://t.co/WZti3ubfng',
#      'id': '1455351457662767115',
#      'conversation_id': '1455351457662767115',
#      'author_id': '2467720274',
#      'created_at': '2021-11-02T01:50:01.000Z'},
#     {'entities': {'annotations': [{'start': 0,
#         'end': 18,
#         'probability': 0.8718,
#         'type': 'Person',
#         'normalized_text': 'Sen. Chuck Grassley'},
#        {'start': 21,
#         'end': 39,
#         'probability': 0.658,
#         'type': 'Person',
#         'normalized_text': 'Rep. Randy Feenstra'},
#        {'start': 46,
#         'end': 68,
#         'probability': 0.8512,
#         'type': 'Person',
#         'normalized_text': 'Rep. Mariannette Miller'},
#        {'start': 70,
#         'end': 74,
#         'probability': 0.5503,
#         'type': 'Person',
#         'normalized_text': 'Meeks'}],
#       'urls': [{'start': 182,
#         'end': 205,
#         'url': 'https://t.co/5UOk2EJAuI',
#         'expanded_url': 'https://buff.ly/2ZJu77y',
#         'display_url': 'buff.ly/2ZJu77y'}]},
#      'text': 'Sen. Chuck Grassley, Rep. Randy Feenstra, and Rep. Mariannette Miller-Meeks happily spent their weekend supporting an anti-LGBTQ, anti-abortion, and anti-contraception organization.\nhttps://t.co/5UOk2EJAuI',
#      'id': '1455319246544723969',
#      'conversation_id': '1455319246544723969',
#      'author_id': '2467720274',
#      'created_at': '2021-11-01T23:42:01.000Z'},
#     {'entities': {'annotations': [{'start': 20,
#         'end': 24,
#         'probability': 0.9897,
#         'type': 'Person',
#         'normalized_text': 'Biden'},
#        {'start': 34,
#         'end': 49,
#         'probability': 0.9407,
#         'type': 'Organization',
#         'normalized_text': 'Democratic Party'},
#        {'start': 80,
#         'end': 90,
#         'probability': 0.8662,
#         'type': 'Organization',
#         'normalized_text': 'Republicans'},
#        {'start': 118,
#         'end': 122,
#         'probability': 0.8585,
#         'type': 'Person',
#         'normalized_text': 'Biden'},
#        {'start': 193,
#         'end': 197,
#         'probability': 0.9991,
#         'type': 'Person',
#         'normalized_text': 'Trump'}],
#       'urls': [{'start': 206,
#         'end': 229,
#         'url': 'https://t.co/HnaV982Sy2',
#         'expanded_url': 'https://buff.ly/3bxoJXI',
#         'display_url': 'buff.ly/3bxoJXI'}]},
#      'text': 'In attempts to hurt Biden and the Democratic Party ahead of upcoming elections, Republicans are pointing out that the Biden administration is keeping more illegal drugs out of the country than Trump did. 🤷 https://t.co/HnaV982Sy2',
#      'id': '1455312450178494470',
#      'conversation_id': '1455312450178494470',
#      'author_id': '2467720274',
#      'created_at': '2021-11-01T23:15:01.000Z'}],
#    'meta': {'newest_id': '1455668545002606605',
#     'oldest_id': '1455312450178494470',
#     'result_count': 16}}}}

# %% [markdown]
# ### Tweets Count Recent

# %%
url="http://api.twitter.com/2/tweets/counts/recent"

handles=['19thnews', 'ABC', 'TheAdvocateMag', 'AFPFactCheck', 'AJEnglish', 'aldotcom', 'AlterNet', 'theamgreatness', 'AmerIndependent']

# %% [markdown]
# #### only for one outlet

# %%
params={'query': 'from:19thnews', # add Twitter handle for outlets here
        'start_time': datetime.datetime.strptime('2021-10-28T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
        'end_time':datetime.datetime.strptime('2021-11-03T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(),
        'granularity': 'day'}
    
tweet_count_single=make_request(headers, params, url)

# %%
tweet_count_single
# Out:
# {'errors': [{'parameters': {'start_time': ['2021-10-28T00:00Z']},
#    'message': "Invalid 'start_time':'2021-10-28T00:00Z'. 'start_time' must be on or after 2021-10-28T07:54Z"}],
#  'title': 'Invalid Request',
#  'detail': 'One or more parameters to your request was invalid.',
#  'type': 'https://api.twitter.com/2/problems/invalid-request'}

# %%
make_df(tweet_count_single)
# Out:
#                         end                     start  tweet_count
# 0  2021-10-29T00:00:00.000Z  2021-10-28T00:00:00.000Z           23
# 1  2021-10-30T00:00:00.000Z  2021-10-29T00:00:00.000Z           19
# 2  2021-10-31T00:00:00.000Z  2021-10-30T00:00:00.000Z            7
# 3  2021-11-01T00:00:00.000Z  2021-10-31T00:00:00.000Z            3
# 4  2021-11-02T00:00:00.000Z  2021-11-01T00:00:00.000Z           24
# 5  2021-11-03T00:00:00.000Z  2021-11-02T00:00:00.000Z           30

# %% [markdown]
# #### for list of outlets

# %%
# loop

# define empty dict:
tweet_count={}

for handle in handles:
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime('2021-10-29T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time':datetime.datetime.strptime('2021-11-04T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(),
            'granularity': 'day'}
    
    tweet_count[f'{handle}']=make_request(headers, params, url)

# %%
# dict to dataframe:
df_tweet_count = pd.DataFrame(list(tweet_count.items()))

# %%
df_tweet_count
# Out:
#                  0                                                  1
# 0         19thnews  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 1              ABC  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 2   TheAdvocateMag  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 3     AFPFactCheck  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 4        AJEnglish  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 5         aldotcom  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 6         AlterNet  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 7   theamgreatness  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...
# 8  AmerIndependent  {'data': [{'end': '2021-10-30T00:00:00.000Z', ...

# %%
for i in range(0, len(df_tweet_count)):
    df_tweet_count.iloc[i,1]=df_tweet_count.iloc[i,1]['meta']['total_tweet_count']

# %%
df_tweet_count
# Out:
#                  0    1
# 0         19thnews  117
# 1              ABC  712
# 2   TheAdvocateMag   59
# 3     AFPFactCheck   21
# 4        AJEnglish  420
# 5         aldotcom  213
# 6         AlterNet  135
# 7   theamgreatness   61
# 8  AmerIndependent   85

# %%
df_tweet_count[1].sum()
# Out:
# 1823

# %% [markdown]
# ### Pagination: Using next_token

# %% [markdown]
# #### only for one outlet

# %%
# make simple request:

# define url:
url="http://api.twitter.com/2/tweets/search/recent"

# define params
params={'query': 'from:AJEnglish', # add Twitter handle for outlets here
        'start_time': datetime.datetime.strptime('2021-10-29T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
        'end_time': datetime.datetime.strptime('2021-11-04T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
        'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
        'max_results': 100} # default is 10, max possible is 100

response=make_request(headers, params, url)
response_df=make_df(response)

while True:
    params['next_token'] = response['meta']['next_token']
    response=make_request(headers, params, url)
    response_df=response_df.append(make_df(response))
    
    if 'next_token' not in  response['meta']:
        break

# %% [markdown]
# #### for list of outlets >> FINAL CODE???

# %%
# make loop request:

# define url:
url="http://api.twitter.com/2/tweets/search/recent"

# define list of Twitter handles
handles=['19thnews', 'ABC', 'TheAdvocateMag', 'AFPFactCheck', 'AJEnglish', 'aldotcom', 'AlterNet', 'theamgreatness', 'AmerIndependent']

# create empty dict:
#response={}

for handle in handles:
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime('2021-10-29T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time': datetime.datetime.strptime('2021-11-04T00:00:00+0000', '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
            'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
            'max_results': 100} # default is 10, max possible is 100
    
    response=make_request(headers, params, url)
    response_df_outlets=make_df(response)
    
    if 'next_token' in  response['meta']:
        while 'next_token' in  response['meta']:
            params['next_token'] = response['meta']['next_token']
            response=make_request(headers, params, url)
            response_df_outlets=response_df_outlets.append(make_df(response))
            
            if 'next_token' not in  response['meta']:
                break

    response_df_outlets.to_csv(f'data/tets_loop_2/{handle}.csv', index=False)

# %%
# open all csv's in that folder and append to one big df:

# create empty df with columns:
all_tweets_outlets = pd.DataFrame(columns=['entities', 'text', 'author_id', 'id', 'conversation_id', 'created_at', 'attachments', 'referenced_tweets'])


for handle in handles:
    all_tweets_outlets=all_tweets_outlets.append(pd.read_csv(f'data/tets_loop_2/{handle}.csv'))

# %%
df_ids
# Out:
#           username            author_id
# 0         19thnews  1219278784693768193
# 1              ABC             28785486
# 2   TheAdvocateMag             21692297
# 3     AFPFactCheck  1002203254065950720
# 4        AJEnglish              4970411
# 5         aldotcom             14528874
# 6         AlterNet             18851248
# 7   theamgreatness   749016639287414784
# 8  AmerIndependent           2467720274

# %%
# author_id: from int to string
all_tweets_outlets['author_id']=all_tweets_outlets['author_id'].astype(str)

# %%
# join with df_ids:
result_tweets_outlets=pd.merge(all_tweets_outlets, df_ids, on='author_id') #.sort_values(by=['username', 'created_at'])

# %%
result_tweets_outlets
# Out:
#                                                entities  \
# 0     {'hashtags': [{'start': 212, 'end': 222, 'tag'...
# 1     {'annotations': [{'start': 28, 'end': 38, 'pro...
# 2     {'urls': [{'start': 188, 'end': 211, 'url': 'h...
# 3     {'urls': [{'start': 202, 'end': 225, 'url': 'h...
# 4     {'mentions': [{'start': 3, 'end': 12, 'usernam...
# ...                                                 ...
# 1818  {'urls': [{'start': 121, 'end': 144, 'url': 'h...
# 1819  {'urls': [{'start': 73, 'end': 96, 'url': 'htt...
# 1820  {'urls': [{'start': 153, 'end': 176, 'url': 'h...
# 1821  {'urls': [{'start': 218, 'end': 241, 'url': 'h...
# 1822  {'urls': [{'start': 159, 'end': 182, 'url': 'h...
#
#                                                    text            author_id  \
# 0     Can You Cure Motherhood Burnout? By giving exh...  1219278784693768193
# 1     RT @bcrodriguez: What could Republicans' wins ...  1219278784693768193
# 2     “There is no other sector of health care in wh...  1219278784693768193
# 3     Wins by Glenn Youngkin, Winsome Sears and Repu...  1219278784693768193
# 4     RT @jayomiko: Congratulations @19thnews Editor...  1219278784693768193
# ...                                                 ...                  ...
# 1818  Far-right extremist groups are using COVID saf...           2467720274
# 1819  RT @CAPAction: And who will pay for it? The ri...           2467720274
# 1820  As noted by one expert, policymakers should no...           2467720274
# 1821  Fox News: Uses images that evoke violence and ...           2467720274
# 1822  Miyares' largest donor of $2.6 million dollars...           2467720274
#
#                        id      conversation_id                created_at  \
# 0     1456041004155424776  1456041004155424776  2021-11-03T23:30:01.000Z
# 1     1456009174928744448  1456009174928744448  2021-11-03T21:23:33.000Z
# 2     1455994444575019009  1455994444575019009  2021-11-03T20:25:01.000Z
# 3     1455987707201695758  1455987707201695758  2021-11-03T19:58:14.000Z
# 4     1455986244203081729  1455986244203081729  2021-11-03T19:52:26.000Z
# ...                   ...                  ...                       ...
# 1818  1454113134361391109  1454113134361391109  2021-10-29T15:49:22.000Z
# 1819  1454109827941154817  1454109827941154817  2021-10-29T15:36:13.000Z
# 1820  1454043086464733197  1454043086464733197  2021-10-29T11:11:01.000Z
# 1821  1453901905659416577  1453901905659416577  2021-10-29T01:50:01.000Z
# 1822  1453877999204511756  1453877999204511756  2021-10-29T00:15:01.000Z
#
#                                     attachments  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 1818                                        NaN
# 1819  {'media_keys': ['3_1454093180249518083']}
# 1820                                        NaN
# 1821                                        NaN
# 1822                                        NaN
#
#                                       referenced_tweets         username
# 0                                                   NaN         19thnews
# 1     [{'type': 'retweeted', 'id': '1455986894890848...         19thnews
# 2                                                   NaN         19thnews
# 3                                                   NaN         19thnews
# 4     [{'type': 'retweeted', 'id': '1455984760870752...         19thnews
# ...                                                 ...              ...
# 1818                                                NaN  AmerIndependent
# 1819  [{'type': 'retweeted', 'id': '1454093185731473...  AmerIndependent
# 1820                                                NaN  AmerIndependent
# 1821                                                NaN  AmerIndependent
# 1822                                                NaN  AmerIndependent
#
# [1823 rows x 9 columns]

# %% [markdown]
# ### Loop with Pagination + time period

# %%
# read handles + start & end dates:
df=pd.read_csv('data/outlets_time_stamps.csv')

handles=df['handle'].tolist()
start_dates=df['start'].tolist()
end_dates=df['end'].tolist()

# %% [markdown]
# #### 1. Tweet Count (optional)

# %%
# define url:
url="http://api.twitter.com/2/tweets/counts/recent"

# %%
# define empty dict:
tweet_count={}

for handle, start, end in zip(handles, start_dates, end_dates):
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime(start, '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time':datetime.datetime.strptime(end, '%Y-%m-%dT%H:%M:%S%z').isoformat(),
            'granularity': 'day'}
    
    tweet_count[f'{handle}']=make_request(headers, params, url)

# %%
# dict to dataframe:
df_tweet_count = pd.DataFrame(list(tweet_count.items()))

# %%
for i in range(0, len(df_tweet_count)):
    df_tweet_count.iloc[i,1]=df_tweet_count.iloc[i,1]['meta']['total_tweet_count']

# %%
df_tweet_count
# Out:
#                 0    1
# 0        19thnews    7
# 1             ABC  604
# 2  TheAdvocateMag   18

# %%
df_tweet_count[1].sum()
# Out:
# 629

# %% [markdown]
# #### 2. Collect Tweets

# %%
# define url:
url="http://api.twitter.com/2/tweets/search/recent"

# %%
for handle, start, end in zip(handles, start_dates, end_dates):
    params={'query': f'from:{handle}', # add Twitter handle for outlets here
            'start_time': datetime.datetime.strptime(start, '%Y-%m-%dT%H:%M:%S%z').isoformat(), # german time => created at 2021-10-23T22:00:00.000Z means 2021-10-24T00:00:00 GERMAN TIME 
            'end_time': datetime.datetime.strptime(end, '%Y-%m-%dT%H:%M:%S%z').isoformat(), 
            'tweet.fields': 'author_id,entities,attachments,conversation_id,created_at,referenced_tweets',
            'max_results': 100} # default is 10, max possible is 100
    
    response=make_request(headers, params, url)
    response_df_outlets=make_df(response)
    
    if 'next_token' in  response['meta']:
        while 'next_token' in  response['meta']:
            params['next_token'] = response['meta']['next_token']
            response=make_request(headers, params, url)
            response_df_outlets=response_df_outlets.append(make_df(response))
            
            if 'next_token' not in  response['meta']:
                break

    response_df_outlets.to_csv(f'data/test_loop_3/{handle}.csv', index=False)

# %%
# create empty df with columns:
all_tweets_outlets = pd.DataFrame(columns=['entities', 'text', 'author_id', 'id', 'conversation_id', 'created_at', 'attachments', 'referenced_tweets'])


for handle in handles:
    all_tweets_outlets=all_tweets_outlets.append(pd.read_csv(f'data/test_loop_3/{handle}.csv'))

# %%
all_tweets_outlets
# Out:
#                                              entities  \
# 0   {'urls': [{'start': 179, 'end': 202, 'url': 'h...
# 1   {'urls': [{'start': 148, 'end': 171, 'url': 'h...
# 2   {'urls': [{'start': 124, 'end': 147, 'url': 'h...
# 3   {'urls': [{'start': 198, 'end': 221, 'url': 'h...
# 4   {'urls': [{'start': 137, 'end': 160, 'url': 'h...
# ..                                                ...
# 13  {'annotations': [{'start': 92, 'end': 114, 'pr...
# 14  {'annotations': [{'start': 15, 'end': 34, 'pro...
# 15  {'urls': [{'start': 33, 'end': 56, 'url': 'htt...
# 16  {'mentions': [{'start': 1, 'end': 13, 'usernam...
# 17  {'hashtags': [{'start': 69, 'end': 82, 'tag': ...
#
#                                                  text            author_id  \
# 0   Texas Gov. Greg Abbott on Monday signed a bill...  1219278784693768193
# 1   “This is more than a short-term problem. Being...  1219278784693768193
# 2   Schools still have not done enough to stop the...  1219278784693768193
# 3   “There is early evidence, in the form of long ...  1219278784693768193
# 4   “Activists have been saying the same thing for...  1219278784693768193
# ..                                                ...                  ...
# 13  A transgender woman working as a security guar...             21692297
# 14  A student at a Missouri high school is the fir...             21692297
# 15  Make the most of your "me time." https://t.co/...             21692297
# 16  .@itsJojoSiwa is making history this year as s...             21692297
# 17  "They had it all. Wealth, style, power. Who wo...             21692297
#
#                      id      conversation_id                created_at  \
# 0   1454550177918881799  1454550177918881799  2021-10-30T20:46:01.000Z
# 1   1454536336745107462  1454536336745107462  2021-10-30T19:51:01.000Z
# 2   1454483737345941510  1454483737345941510  2021-10-30T16:22:00.000Z
# 3   1454467380684500997  1454467380684500997  2021-10-30T15:17:00.000Z
# 4   1454300278904266758  1454300278904266758  2021-10-30T04:13:00.000Z
# ..                  ...                  ...                       ...
# 13  1454840598947565569  1454840598947565569  2021-10-31T16:00:03.000Z
# 14  1454795301500248072  1454795301500248072  2021-10-31T13:00:03.000Z
# 15  1454659393685966852  1454659393685966852  2021-10-31T04:00:00.000Z
# 16  1454614099279548418  1454614099279548418  2021-10-31T01:00:01.000Z
# 17  1454568797210173440  1454568797210173440  2021-10-30T22:00:00.000Z
#
#    attachments referenced_tweets
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
# ..         ...               ...
# 13         NaN               NaN
# 14         NaN               NaN
# 15         NaN               NaN
# 16         NaN               NaN
# 17         NaN               NaN
#
# [629 rows x 8 columns]

# %% [markdown]
# #### 3. Collet Twitter id's to all outlets
#
# see above (line 12)

# %% [markdown]
# ### Final code requires:
# 1. Collect Twitter id's to all Outlets
# 2. Optional: collect number of tweets (count) to verify if loop was correct
# 3. Run loop over Twitter handles and store one csv for each outlet
